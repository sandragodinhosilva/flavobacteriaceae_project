# %% [markdown]
# # BGC analysis

# %% [markdown]
# Author: Sandra Godinho Silva \
# Creation date: 2/10/2020 \
# Version: 0.3

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 1000)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Metadata

# %%
metadata = pd.read_csv("All_info.csv")
metadata.head(2)
# Out:
#   Assembly accession                             Bin_Id  \
# 0    GCA_000016645.1  GCA_000016645.1_ASM1664v1_genomic
# 1    GCA_000023285.1  GCA_000023285.1_ASM2328v1_genomic
#
#                    Marker lineage  Completeness  Contamination  \
# 0  f__Flavobacteriaceae (UID2817)         99.65           0.14
# 1      p__Bacteroidetes (UID2605)        100.00           0.00
#
#    Strain_heterogeneity  Quality_score  \
# 0                   0.0          98.95
# 1                   0.0         100.00
#
#                                       classification    Domain         Phyla  \
# 0  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
#
#          Class             Order             Family           Genus  \
# 0  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Flavobacterium
# 1  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Capnocytophaga
#
# ...

# %%
# Out:
#                    Assembly accession
# Genus
# AU392                               2
# Aequorivita                        42
# Algibacter                          9
# Algibacter_A                        1
# Algibacter_B                        5
# ...                               ...
# YIM-102668                          2
# Zeaxanthinibacter                   3
# Zhouia                              2
# Zobellia                            6
# Zunongwangia                       13
#
# [175 rows x 1 columns]

# %% [markdown]
# ## Number BGCs per type

# %%
bgc = pd.read_csv("../../3_Annotation/antismash_results/BGCs_resumed.csv")
bgc = bgc.set_index("index").T
bgc["Nr_BGCs"] = bgc.sum(axis=1)
bgc.head()
# Out:
# index            NRPS  NRPS_PKS_hybrid  NRPS_other  Others  PKSI  PKSIII  \
# GCA_002831645.1     0                0           0       1     0       1
# GCA_001971785.1     0                0           0       0     0       0
# GCA_002951395.1     0                0           0       0     0       0
# GCA_903969135.1     1                0           0       1     0       0
# GCA_009664855.1     0                0           0       2     0       1
#
# index            PKS_other  RiPPs  Siderophore  terpene  transAT_PSK  Nr_BGCs
# GCA_002831645.1          0      1            0        1            0        4
# GCA_001971785.1          0      1            0        1            0        2
# GCA_002951395.1          0      0            1        1            0        2
# GCA_903969135.1          1      3            1        1            0        8
# GCA_009664855.1          0      2            0        2            0        7

# %% [markdown]
# ## All information about each BGC

# %%
bgc_info = pd.read_csv("../../3_Annotation/antismash_results/all_BGC_info.csv")
bgc_info = bgc_info.rename(columns={"Most_similar_known_ cluster":"Most_similar_known_cluster"})
bgc_info.head(2)
# Out:
#             Genome   Region_Type    antiSMASH_classif new_classif       From  \
# 0  GCA_002831645.1  Region&nbsp1                T3PKS      PKSIII   582350.0
# 1  GCA_002831645.1  Region&nbsp2  terpene,bacteriocin      Others  1879449.0
#
#         To  Size(bp) Most_similar_known_cluster Most_similar_classif  \
# 0   623402   41052.0                        NaN                  NaN
# 1  1909353   29904.0                        NaN                  NaN
#
#   Similarity                     Correct_name
# 0        NaN  GCA_002831645_contig1.region001
# 1        NaN  GCA_002831645_contig1.region002

# %%
len(bgc_info)
# Out:
# 9330

# %%
bgc_known = bgc_info[bgc_info["Most_similar_classif"].notnull()]
bgc_known.head(2)
# Out:
#             Genome   Region_Type antiSMASH_classif new_classif       From  \
# 2  GCA_002831645.1  Region&nbsp3           terpene     terpene  2137564.0
# 5  GCA_001971785.1  Region&nbsp2           terpene     terpene  2834169.0
#
#         To  Size(bp) Most_similar_known_cluster Most_similar_classif  \
# 2  2160010   22446.0                 carotenoid              Terpene
# 5  2855008   20839.0                 carotenoid              Terpene
#
#   Similarity                     Correct_name
# 2        28%  GCA_002831645_contig1.region003
# 5        28%  GCA_001971785_contig1.region002

# %%
len(bgc_known)
# Out:
# 4344

# %% [markdown]
# ### Merge with metadata:

# %%
bgc_known_metadata = pd.merge(bgc_known, metadata, how="left", left_on="Genome", right_on="Assembly accession")
#bgc_known_metadata = merged.set_index("Genome")
bgc_known_metadata.head(2)
# Out:
#             Genome   Region_Type antiSMASH_classif new_classif       From  \
# 0  GCA_002831645.1  Region&nbsp3           terpene     terpene  2137564.0
# 1  GCA_001971785.1  Region&nbsp2           terpene     terpene  2834169.0
#
#         To  Size(bp) Most_similar_known_cluster Most_similar_classif  \
# 0  2160010   22446.0                 carotenoid              Terpene
# 1  2855008   20839.0                 carotenoid              Terpene
#
#   Similarity                     Correct_name Assembly accession  \
# 0        28%  GCA_002831645_contig1.region003    GCA_002831645.1
# 1        28%  GCA_001971785_contig1.region002    GCA_001971785.1
#
#                                 Bin_Id         Marker lineage  Completeness  \
# 0  GCA_002831645.1_ASM283164v1_genomic  s__algicola (UID2846)         99.67
# 1  GCA_001971785.1_ASM197178v1_genomic  s__algicola (UID2846)         98.35
#
#    Contamination  Strain_heterogeneity  Quality_score  \
# ...

# %%
#bgc_known_metadata.groupby(["Most_similar_known_cluster","Family"]).count()

# %%
df = bgc_known_metadata.groupby(["Family", "Most_similar_known_cluster"]).count()["Genome"].reset_index().rename(columns={"Genome":"Counts per family"})
df = df.pivot(index='Most_similar_known_cluster', columns='Family', values='Counts per family')
df1 = df.fillna(0).reset_index()
df1.head()
# Out:
# Family                         Most_similar_known_cluster  Flavobacteriaceae  \
# 0                                           1-heptadecene                4.0
# 1                 1-nonadecene / (14Z)-1,14-nonadecadiene                1.0
# 2       CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a ...                1.0
# 3                                                  ET-743               29.0
# 4                             K53 capsular polysaccharide                1.0
#
# Family  Weeksellaceae
# 0                 0.0
# 1                 0.0
# 2                 2.0
# 3                 0.0
# 4                 1.0

# %%
df_origin = bgc_known_metadata.groupby(["Origin", "Most_similar_known_cluster"]).count()["Genome"].reset_index().rename(columns={"Genome":"Counts"})
df_origin = df_origin.pivot(index='Most_similar_known_cluster', columns='Origin', values='Counts')
df_origin = df_origin.fillna(0).reset_index()
df_origin.head()
# Out:
# Origin                         Most_similar_known_cluster  Marine  Non_marine  \
# 0                                           1-heptadecene     3.0         0.0
# 1                 1-nonadecene / (14Z)-1,14-nonadecadiene     0.0         0.0
# 2       CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a ...     2.0         0.0
# 3                                                  ET-743     8.0         4.0
# 4                             K53 capsular polysaccharide     1.0         0.0
#
# Origin  Unclassified
# 0                1.0
# 1                1.0
# 2                1.0
# 3               17.0
# 4                1.0

# %% [markdown]
# ## Known clusters

# %%
df = bgc_known["Most_similar_known_cluster"].value_counts().rename_axis('BGC').reset_index(name='counts')

# %%
df.head()
# Out:
#                          BGC  counts
# 0                 carotenoid    2117
# 1                 flexirubin    1234
# 2  putrebactin / avaroferrin     392
# 3              bisucaberin B     180
# 4             bacillomycin D      64

# %%
merge= pd.merge(df, df1, how="left", left_on="BGC", right_on="Most_similar_known_cluster")
merge.head()
# Out:
#                          BGC  counts Most_similar_known_cluster  \
# 0                 carotenoid    2117                 carotenoid
# 1                 flexirubin    1234                 flexirubin
# 2  putrebactin / avaroferrin     392  putrebactin / avaroferrin
# 3              bisucaberin B     180              bisucaberin B
# 4             bacillomycin D      64             bacillomycin D
#
#    Flavobacteriaceae  Weeksellaceae
# 0             1584.0          533.0
# 1              828.0          406.0
# 2               53.0          339.0
# 3              143.0           37.0
# 4               62.0            2.0

# %%
compounds = merge[(merge["counts"]>7)]["BGC"].to_list()
print(compounds)
# Out:
# ['carotenoid', 'flexirubin', 'putrebactin / avaroferrin', 'bisucaberin B', 'bacillomycin D', 'pinensins', 'colanic acid', 'ET-743', 'polysaccharide B', 'desferrioxamine E', 'berninamycin A', 'zwittermicin A', 'bacillaene', 'WLIP', 'phormidolide', 'eicosapentaenoic acid-like compound', 'anabaenopeptin NZ857 / nostamide A']

# %%
merge = merge.replace({"N-myristoyl-D-asparagine / cis-7-tetradecenoyl-D-asparagine / (R)-N1-((S)-5-oxohexan-2-yl)-2-tetradecanamidosuccinamide": "N-myristoyl-D-asparagine",
                       "carotenoid":"Carotenoid",
                       "flexirubin":"Flexirubin",
                       "putrebactin / avaroferrin":"Putrebactin/Avaroferrin",
                       "bisucaberin B":"Bisucaberin B",
                       "ET-743":"ET-743 (Trabectedin)",
                       "bacillomycin D":"Bacillomycin D",
                       "pinensins":"Pinensins",
                       "colanic acid":"Colanic acid",
                       "polysaccharide B":"Polysaccharide B",
                       "desferrioxamine E":"Desferioxiamine E",
                       "berninamycin A":"Berninamycin A",
                       "bacillaene":"Bacillaene",
                       "zwittermicin A":"Zwittermicin A",
                       "phormidolide":"Phormidolide",
                       "anabaenopeptin NZ857 / nostamide A":"Anabaenopeptin NZ857/Nostamide A",
                       "eicosapentaenoic acid-like compound":"Eicosapentaenoic acid-like compound",
                      })

# %%
sns.set_style({'font.family': 'Arial'})
#sns.set(style="whitegrid")
sns.set_context("paper", font_scale=1.5) 

plot = merge[(merge["counts"]>7)].sort_values(by="counts", ascending=True).drop(columns="counts").plot(kind="barh", x="BGC", stacked=True,  figsize=(15,4))
plot.legend(loc='center left',bbox_to_anchor=(1.0, 0.5));
plot.set_ylabel("Known BGCs")
plot.set_xlabel("Counts")
fig = plot.get_figure()
fig.savefig("known_clusters.svg", dpi=300, bbox_inches='tight')

# %%
x = merge[(merge["counts"]>7)]#~
x = x.rename(columns={"counts":"Total_BGCs"})
merge_origin = pd.merge(x.drop(columns="Most_similar_known_cluster"),df_origin, how="left", left_on="BGC", right_on="Most_similar_known_cluster").drop(columns="Most_similar_known_cluster")
#merge_origin.head()
merge_origin.to_csv("Known_compounds.csv")

# %%
sns.set_style({'font.family': 'Arial'})
#sns.set(style="white")
sns.set_context("paper", font_scale=1.3) 

merge[merge["counts"] >= 30].drop(columns="counts").plot(kind="barh", x="BGC", stacked=True,figsize=(10,3))

#plt.savefig("known_more_29.pdf", dpi=300, bbox_inches='tight')
# Out:
# <AxesSubplot:ylabel='BGC'>

# %%
sns.set_style({'font.family': 'Arial'})
#sns.set(style="white")
sns.set_context("paper", font_scale=1.3) 

plot = merge[(merge["counts"] < 30) & (merge["counts"]>4)].drop(columns="counts").plot(kind="barh", x="BGC", stacked=True, figsize=(10,4))
fig = plot.get_figure()
#fig.savefig("less_than_30.pdf", dpi=300, bbox_inches='tight')

# %% [markdown]
# # Known compounds per genus

# %%
bgc_known_metadata[bgc_known_metadata["Most_similar_known_cluster"]=="flexirubin"][["Genus", "Most_similar_known_cluster"]]
# Out:
#                  Genus Most_similar_known_cluster
# 5     Chryseobacterium                 flexirubin
# 6       Flavobacterium                 flexirubin
# 10             Mesonia                 flexirubin
# 12      Flavobacterium                 flexirubin
# 17      Flavobacterium                 flexirubin
# ...                ...                        ...
# 4329    Flavobacterium                 flexirubin
# 4331    Flavobacterium                 flexirubin
# 4335        Maribacter                 flexirubin
# 4340  Chryseobacterium                 flexirubin
# 4342  Chryseobacterium                 flexirubin
#
# [1234 rows x 2 columns]

# %%
df = bgc_known_metadata[bgc_known_metadata["Most_similar_known_cluster"]=="flexirubin"][["Genus", "Most_similar_known_cluster"]].groupby("Genus").count()

df_total1 = metadata[["Assembly accession","Genus", "Family"]].groupby(["Genus", "Family"]).count().rename(columns={"Assembly accession":"Total genomes per genus"})
df_total2 = bgc_known_metadata[["Assembly accession","Genus", "Family"]].groupby(["Genus", "Family"]).count().rename(columns={"Assembly accession":"Total BGCs per genus"})

merge = pd.merge(df, df_total1, how="right", left_index=True, right_index=True)
merge = pd.merge(merge, df_total2, how="right", left_index=True, right_index=True)
merge = merge.fillna(0)
merge = merge.rename(columns={"Most_similar_known_cluster":"Flexirubin counts"})
merge["%"] = (merge["Flexirubin counts"]/merge["Total BGCs per genus"]*100).round(1)

merge = merge.sort_values(by=["Family", "Genus"])
merge = merge[(merge["Total genomes per genus"]>7)]
merge = merge.reset_index()
merge.head(50)
# Out:
#                       Genus             Family  Flexirubin counts  \
# 0               Aequorivita  Flavobacteriaceae               39.0
# 1                Algibacter  Flavobacteriaceae                0.0
# 2                Aquimarina  Flavobacteriaceae               26.0
# 3               Arenibacter  Flavobacteriaceae               15.0
# 4                    BACL21  Flavobacteriaceae                0.0
# 5              CG1-02-35-72  Flavobacteriaceae                0.0
# 6              CG2-30-34-30  Flavobacteriaceae                0.0
# 7            Capnocytophaga  Flavobacteriaceae               77.0
# 8              Cellulophaga  Flavobacteriaceae                1.0
# 9               Croceivirga  Flavobacteriaceae                0.0
# 10                 Dokdonia  Flavobacteriaceae                0.0
# 11               Euzebyella  Flavobacteriaceae               11.0
# 12           Flavobacterium  Flavobacteriaceae              382.0
# ...

# %%
#plt.style.use('fivethirtyeight') 
ax = merge[["Genus","%"]].plot(kind="bar", figsize=(15,5),width=0.6, x="Genus")

plt.ylabel('% BGCs == Flexirubin')
plt.xticks(rotation=45, horizontalalignment='right')

plt.tight_layout()
plt.show()

ax.figure.savefig("Percentage_flexirubin.svg", dpi=300)
