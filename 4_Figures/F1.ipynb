# %% [markdown]
# # Figure 1

# %% [markdown]
# Author: Sandra Godinho Silva \
# Creation date: 23/09/2020 \
# Version: 0.2 (1/01/2021)

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


# %matplotlib inline
#plt.style.use('seaborn-whitegrid')
import numpy as np

# %%
pd.set_option('display.max_columns', 1000)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# ## Imports

# %%
metrics = pd.read_csv("../../1_Dataset_creation/Dataset.csv")
metrics = metrics.rename(columns={"Genome_ID":"Assembly accession"})
metrics.head(2)
# Out:
#   Assembly accession                             Bin_Id  \
# 0    GCA_000016645.1  GCA_000016645.1_ASM1664v1_genomic
# 1    GCA_000023285.1  GCA_000023285.1_ASM2328v1_genomic
#
#                    Marker lineage  Completeness  Contamination  \
# 0  f__Flavobacteriaceae (UID2817)         99.65           0.14
# 1      p__Bacteroidetes (UID2605)        100.00           0.00
#
#    Strain_heterogeneity  Quality_score  \
# 0                   0.0          98.95
# 1                   0.0         100.00
#
#                                       classification    Domain         Phyla  \
# 0  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
#
#          Class             Order             Family           Genus  \
# 0  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Flavobacterium
# 1  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Capnocytophaga
#
#                      Species  n_scaffolds  n_contigs  scaf_bp  contig_bp  \
# 0  Flavobacterium johnsoniae            1          1  6096872    6096872
# 1    Capnocytophaga ochracea            1          1  2612925    2612925
#
#    gap_pct  scaf_N50  scaf_L50  ctg_N50  ctg_L50  scaf_N90  scaf_L90  ctg_N90  \
# 0      0.0         1   6096872        1  6096872         1   6096872        1
# 1      0.0         1   2612925        1  2612925         1   2612925        1
#
#    ctg_L90  scaf_max  ctg_max  scaf_n_gt50K  scaf_pct_gt50K   gc_avg  gc_std  \
# 0  6096872   6096872  6096872             1           100.0  0.34113     0.0
# 1  2612925   2612925  2612925             1           100.0  0.39588     0.0
#
#   Classification_quality
# 0                   High
# 1                   High

# %%
metadata = pd.read_csv("../../2_Metadata/Metadata_final.csv")
metadata.head(2)
# Out:
#   Assembly accession   ASM name Alias Altitude Anonymized name  \
# 0    GCA_000016645.1  ASM1664v1   NaN      NaN             NaN
# 1    GCA_000023285.1  ASM2328v1   NaN      NaN             NaN
#
#   Arrayexpress species Arrayexpress strain or line   Assembly level  \
# 0                  NaN                         NaN  Complete Genome
# 1                  NaN                         NaN  Complete Genome
#
#   Assembly method Biomaterial provider Bioproject accession  \
# 0             NaN                  NaN           PRJNA16082
# 1             NaN                  NaN           PRJNA29403
#
#   Biosample accession Biosample model  \
# 0        SAMN02598357             NaN
# 1        SAMN00001911             NaN
#
#                                      Biosample title Biotic relationship  \
# 0        Sample from Flavobacterium johnsoniae UW101                 NaN
# 1  Generic sample from Capnocytophaga ochracea DS...                 NaN
#
#   Body sample site Cell shape Collected by Collection date  \
# 0              NaN        Rod          NaN             NaN
# 1              NaN        Rod          NaN             NaN
#
#                                    Comment paragraph       Completion date  \
# 0  Flavobacterium johnsoniae ATCC 17061. Flavobac...  2007-05-01T00:00:00Z
# 1                   Capnocytophaga ochracea DSM 7271  2009-04-30T00:00:00Z
#
#   Contact email Contact lab  Contigs Country Culture collection Depth  \
# 0           NaN         NaN      1.0     NaN         ATCC 17061   NaN
# 1           NaN         NaN      1.0     NaN           DSM 7271   NaN
#
#   Derived from Description Disease ENA checklist ENA-first-public  \
# 0          NaN         NaN     NaN           NaN              NaN
# 1          NaN         NaN     NaN           NaN              NaN
#
#   ENA-last-update Elevation Env biome Env broad scale Env feature  \
# 0             NaN       NaN       NaN             NaN         NaN
# 1             NaN       NaN       NaN             NaN         NaN
#
#   Env local scale Env material Env medium Environment Environmental sample  \
# 0             NaN          NaN        NaN         NaN                  NaN
# 1             NaN          NaN        NaN         NaN                  NaN
#
#   Estimated size Excluded from refseq FDA cvm ID  \
# 0            NaN                  NaN        NaN
# 1            NaN                  NaN        NaN
#
#   Finishing strategy (depth of coverage) First name  \
# 0                                    NaN        NaN
# 1                                    NaN        NaN
#
#                                             Ftp path GOLD stamp ID  \
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...           NaN
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...           NaN
#
#    Gbrs paired ASM Genbank accessions Gene calling method  \
# 0  GCF_000016645.1           CP000685                 NaN
# 1  GCF_000023285.1           CP001632                 NaN
#
#                         Genome name Genome quality flags Genome rep  \
# 0   Flavobacterium johnsoniae UW101                  NaN       Full
# 1  Capnocytophaga ochracea DSM 7271                  NaN       Full
#
#   Genome status Genotype      Geographic location Geographic location (city)  \
# 0      Complete      NaN  United Kingdom: England                    England
# 1      Complete      NaN                      NaN                        NaN
#
#   Geographic location (country or region) Gram stain          Habitat  \
# 0                          United Kingdom        NaN         Multiple
# 1                                     NaN        NaN  Host-associated
#
#                   Host Host age Host disease Host disease outcome Host gender  \
# 0                  NaN      NaN          NaN                  NaN         NaN
# 1  Human, homo sapiens      NaN          NaN                  NaN         NaN
#
#   Host health            Host name Host scientific name Host sex  Host taxid  \
# 0         NaN                  NaN                  NaN      NaN         NaN
# 1         NaN  Human, Homo sapiens                  NaN      NaN         NaN
#
#   Host tissue sampled INSDC center alias INSDC center name INSDC first public  \
# 0                 NaN                NaN               NaN                NaN
# 1                 NaN                NaN               NaN                NaN
#
#   INSDC last update INSDC status Identification method Identified by  \
# 0               NaN          NaN                   NaN           NaN
# 1               NaN          NaN                   NaN           NaN
#
#          Infraspecific name Investigation type Isol growth condt Isolate  \
# 0  strain=UW101; ATCC 17061                NaN               NaN     NaN
# 1           strain=DSM 7271                NaN               NaN     NaN
#
#                                   Isolation comments Isolation country  \
# 0  isolated from soil in England and is the type ...    United Kingdom
# 1                isolated from the human oral cavity               NaN
#
#   Isolation site       Isolation source Last name Latitude Locus tag prefix  \
# 0            NaN                   soil       NaN      NaN              NaN
# 1            NaN  the human oral cavity       NaN      NaN              NaN
#
#   Longitude MLST Mapping method and version Material Metagenome source  \
# 0       NaN  NaN                        NaN      NaN               NaN
# 1       NaN  NaN                        NaN      NaN               NaN
#
#   Misc param Misc param: hmp supersite Motility  \
# 0        NaN                       NaN      Yes
# 1        NaN                       NaN      Yes
#
#                                                 Name  Ncbi taxon ID Note  \
# 0                                               NCBI       376686.0  NaN
# 1  Joint Genome Institute, U.S. Department of Energy       521097.0  NaN
#
#                            Organism                     Organism name  \
# 0   Flavobacterium johnsoniae UW101   Flavobacterium johnsoniae UW101
# 1  Capnocytophaga ochracea DSM 7271  Capnocytophaga ochracea DSM 7271
#
#   Other clinical Other environmental Oxygen requirement Paired ASM comp  \
# 0            NaN                 NaN            Aerobic       identical
# 1            NaN                 NaN        Facultative       identical
#
#   Phenotypes  Plasmids Project name Project type Publication  \
# 0        NaN       NaN          NaN          NaN         NaN
# 1        NaN       NaN          NaN          NaN    21304645
#
#           Publication date Ref biomaterial Refseq accessions  \
# 0  2014-01-28T00:00:00.000             NaN         NC_009441
# 1  2009-02-19T00:00:00.000             NaN         NC_013162
#
#          Refseq category  Refseq cds Rel to oxygen  \
# 0  representative genome      5017.0           NaN
# 1  representative genome      2171.0           NaN
#
#      Relation to type material Release type        SRA accession  \
# 0  assembly from type material        Major                  NaN
# 1  assembly from type material        Major  SRR013476,SRR013477
#
#          Salinity Sample accession Sample name Sample type Seq rel date  \
# 0  Non-halophilic     SAMN02598357    CP000685         NaN   2007/05/01
# 1             NaN     SAMN00001911        FWCB         NaN   2009/08/26
#
#                                   Sequencing centers Sequencing depth  \
# 0                         DOE Joint Genome Institute              NaN
# 1  US DOE Joint Genome Institute (JGI-PGF)|DOE Jo...              NaN
#
#   Sequencing method Sequencing platform Sequencing platform resumed  \
# 0               NaN                 NaN                         NaN
# 1               NaN                 NaN                         NaN
#
#   Sequencing status Source mat ID  Species taxid Specific host Sporulation  \
# 0          complete           NaN          986.0           NaN          No
# 1          complete           NaN         1018.0           NaN          No
#
#        Strain Strain name alias Subject ID Submission model  \
# 0  ATCC 17061               NaN        NaN          Generic
# 1    DSM 7271               NaN        NaN          Generic
#
#   Submission package                                Submitter Subsrc note  \
# 0        Generic.1.0            US DOE Joint Genome Institute         NaN
# 1        Generic.1.0  US DOE Joint Genome Institute (JGI-PGF)         NaN
#
#   Supplier name     Taxid Temperature Temperature optimum Temperature range  \
# 0           NaN  376686.0         NaN               20-30        Mesophilic
# 1           NaN  521097.0         NaN               35-37        Mesophilic
#
#   Title Trophic level                             Type material Type strain  \
# 0   NaN           NaN  type strain of Flavobacterium johnsoniae         Yes
# 1   NaN           NaN    type strain of Capnocytophaga ochracea         Yes
#
#   Value Version status WGS master   pH Terrestrial_coordinates    MAG  \
# 0   NaN         latest        NaN  NaN                     NaN  False
# 1   NaN         latest        NaN  NaN                     NaN  False
#
#        Origin
# 0  Non_marine
# 1  Non_marine

# %%
statistics = pd.read_csv("../../3_Annotation/Statistics.csv")
statistics = statistics.rename(columns={"Unnamed: 0":"Assembly accession"})
statistics.head(2)
# Out:
#   Assembly accession  orfs  pfam    ko   cog  cazymes  Orfs_anno_ko%  \
# 0    GCA_002431085.1  2758  4628  1162  1809       47      42.131980
# 1    GCA_002302445.1  2226  3776   859  1364       65      38.589398
#
#    Orfs_anno_cog%  Orfs_anno_cazymes%
# 0       65.591008            1.704133
# 1       61.275831            2.920036

# %%
statistics.describe()
# Out:
#               orfs         pfam           ko          cog      cazymes  \
# count  2681.000000  2681.000000  2681.000000  2681.000000  2681.000000
# mean   3199.770235  5272.502424  1231.480045  2000.995151    88.091011
# std     955.167195  1434.360160   291.250417   537.250808    51.359604
# min     552.000000  1103.000000   325.000000   454.000000     8.000000
# 25%    2536.000000  4274.000000  1020.000000  1610.000000    53.000000
# 50%    3172.000000  5351.000000  1257.000000  2012.000000    81.000000
# 75%    3825.000000  6244.000000  1431.000000  2375.000000   108.000000
# max    7961.000000  8877.000000  1978.000000  3349.000000   316.000000
#
#        Orfs_anno_ko%  Orfs_anno_cog%  Orfs_anno_cazymes%
# count    2681.000000     2681.000000         2681.000000
# mean       39.462142       63.335659            2.656457
# std         4.173492        4.446347            1.068066
# min        14.633840       26.767994            0.590120
# 25%        36.768150       60.596850            1.964840
# 50%        39.174389       63.353500            2.432147
# 75%        41.563636       65.752186            3.011259
# max        58.876812       82.246377            8.152511

# %% [markdown]
# ## Merge

# %%
dataset = pd.merge(metrics, statistics, how="left", left_on="Assembly accession", right_on="Assembly accession", indicator="merge")
dataset["merge"].value_counts()
# Out:
# both          2681
# right_only       0
# left_only        0
# Name: merge, dtype: int64

# %%
dataset = pd.merge(dataset, metadata, how="left", left_on="Assembly accession", right_on="Assembly accession", indicator="merge2")
dataset["merge2"].value_counts()
# Out:
# both          2680
# left_only        1
# right_only       0
# Name: merge2, dtype: int64

# %%
dataset.drop(columns=["merge", "merge2"], inplace=True)
dataset.head(2)
# Out:
#   Assembly accession                             Bin_Id  \
# 0    GCA_000016645.1  GCA_000016645.1_ASM1664v1_genomic
# 1    GCA_000023285.1  GCA_000023285.1_ASM2328v1_genomic
#
#                    Marker lineage  Completeness  Contamination  \
# 0  f__Flavobacteriaceae (UID2817)         99.65           0.14
# 1      p__Bacteroidetes (UID2605)        100.00           0.00
#
#    Strain_heterogeneity  Quality_score  \
# 0                   0.0          98.95
# 1                   0.0         100.00
#
#                                       classification    Domain         Phyla  \
# 0  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
#
#          Class             Order             Family           Genus  \
# 0  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Flavobacterium
# 1  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Capnocytophaga
#
#                      Species  n_scaffolds  n_contigs  scaf_bp  contig_bp  \
# 0  Flavobacterium johnsoniae            1          1  6096872    6096872
# 1    Capnocytophaga ochracea            1          1  2612925    2612925
#
#    gap_pct  scaf_N50  scaf_L50  ctg_N50  ctg_L50  scaf_N90  scaf_L90  ctg_N90  \
# 0      0.0         1   6096872        1  6096872         1   6096872        1
# 1      0.0         1   2612925        1  2612925         1   2612925        1
#
#    ctg_L90  scaf_max  ctg_max  scaf_n_gt50K  scaf_pct_gt50K   gc_avg  gc_std  \
# 0  6096872   6096872  6096872             1           100.0  0.34113     0.0
# 1  2612925   2612925  2612925             1           100.0  0.39588     0.0
#
#   Classification_quality  orfs  pfam    ko   cog  cazymes  Orfs_anno_ko%  \
# 0                   High  5192  8348  1843  3127      244      35.496918
# 1                   High  2182  3871   907  1353       88      41.567369
#
#    Orfs_anno_cog%  Orfs_anno_cazymes%   ASM name Alias Altitude  \
# 0       60.227273            4.699538  ASM1664v1   NaN      NaN
# 1       62.007333            4.032997  ASM2328v1   NaN      NaN
#
#   Anonymized name Arrayexpress species Arrayexpress strain or line  \
# 0             NaN                  NaN                         NaN
# 1             NaN                  NaN                         NaN
#
#     Assembly level Assembly method Biomaterial provider Bioproject accession  \
# 0  Complete Genome             NaN                  NaN           PRJNA16082
# 1  Complete Genome             NaN                  NaN           PRJNA29403
#
#   Biosample accession Biosample model  \
# 0        SAMN02598357             NaN
# 1        SAMN00001911             NaN
#
#                                      Biosample title Biotic relationship  \
# 0        Sample from Flavobacterium johnsoniae UW101                 NaN
# 1  Generic sample from Capnocytophaga ochracea DS...                 NaN
#
#   Body sample site Cell shape Collected by Collection date  \
# 0              NaN        Rod          NaN             NaN
# 1              NaN        Rod          NaN             NaN
#
#                                    Comment paragraph       Completion date  \
# 0  Flavobacterium johnsoniae ATCC 17061. Flavobac...  2007-05-01T00:00:00Z
# 1                   Capnocytophaga ochracea DSM 7271  2009-04-30T00:00:00Z
#
#   Contact email Contact lab  Contigs Country Culture collection Depth  \
# 0           NaN         NaN      1.0     NaN         ATCC 17061   NaN
# 1           NaN         NaN      1.0     NaN           DSM 7271   NaN
#
#   Derived from Description Disease ENA checklist ENA-first-public  \
# 0          NaN         NaN     NaN           NaN              NaN
# 1          NaN         NaN     NaN           NaN              NaN
#
#   ENA-last-update Elevation Env biome Env broad scale Env feature  \
# 0             NaN       NaN       NaN             NaN         NaN
# 1             NaN       NaN       NaN             NaN         NaN
#
#   Env local scale Env material Env medium Environment Environmental sample  \
# 0             NaN          NaN        NaN         NaN                  NaN
# 1             NaN          NaN        NaN         NaN                  NaN
#
#   Estimated size Excluded from refseq FDA cvm ID  \
# 0            NaN                  NaN        NaN
# 1            NaN                  NaN        NaN
#
#   Finishing strategy (depth of coverage) First name  \
# 0                                    NaN        NaN
# 1                                    NaN        NaN
#
#                                             Ftp path GOLD stamp ID  \
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...           NaN
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...           NaN
#
#    Gbrs paired ASM Genbank accessions Gene calling method  \
# 0  GCF_000016645.1           CP000685                 NaN
# 1  GCF_000023285.1           CP001632                 NaN
#
#                         Genome name Genome quality flags Genome rep  \
# 0   Flavobacterium johnsoniae UW101                  NaN       Full
# 1  Capnocytophaga ochracea DSM 7271                  NaN       Full
#
#   Genome status Genotype      Geographic location Geographic location (city)  \
# 0      Complete      NaN  United Kingdom: England                    England
# 1      Complete      NaN                      NaN                        NaN
#
#   Geographic location (country or region) Gram stain          Habitat  \
# 0                          United Kingdom        NaN         Multiple
# 1                                     NaN        NaN  Host-associated
#
#                   Host Host age Host disease Host disease outcome Host gender  \
# 0                  NaN      NaN          NaN                  NaN         NaN
# 1  Human, homo sapiens      NaN          NaN                  NaN         NaN
#
#   Host health            Host name Host scientific name Host sex  Host taxid  \
# 0         NaN                  NaN                  NaN      NaN         NaN
# 1         NaN  Human, Homo sapiens                  NaN      NaN         NaN
#
#   Host tissue sampled INSDC center alias INSDC center name INSDC first public  \
# 0                 NaN                NaN               NaN                NaN
# 1                 NaN                NaN               NaN                NaN
#
#   INSDC last update INSDC status Identification method Identified by  \
# 0               NaN          NaN                   NaN           NaN
# 1               NaN          NaN                   NaN           NaN
#
#          Infraspecific name Investigation type Isol growth condt Isolate  \
# 0  strain=UW101; ATCC 17061                NaN               NaN     NaN
# 1           strain=DSM 7271                NaN               NaN     NaN
#
#                                   Isolation comments Isolation country  \
# 0  isolated from soil in England and is the type ...    United Kingdom
# 1                isolated from the human oral cavity               NaN
#
#   Isolation site       Isolation source Last name Latitude Locus tag prefix  \
# 0            NaN                   soil       NaN      NaN              NaN
# 1            NaN  the human oral cavity       NaN      NaN              NaN
#
#   Longitude MLST Mapping method and version Material Metagenome source  \
# 0       NaN  NaN                        NaN      NaN               NaN
# 1       NaN  NaN                        NaN      NaN               NaN
#
#   Misc param Misc param: hmp supersite Motility  \
# 0        NaN                       NaN      Yes
# 1        NaN                       NaN      Yes
#
#                                                 Name  Ncbi taxon ID Note  \
# 0                                               NCBI       376686.0  NaN
# 1  Joint Genome Institute, U.S. Department of Energy       521097.0  NaN
#
#                            Organism                     Organism name  \
# 0   Flavobacterium johnsoniae UW101   Flavobacterium johnsoniae UW101
# 1  Capnocytophaga ochracea DSM 7271  Capnocytophaga ochracea DSM 7271
#
#   Other clinical Other environmental Oxygen requirement Paired ASM comp  \
# 0            NaN                 NaN            Aerobic       identical
# 1            NaN                 NaN        Facultative       identical
#
#   Phenotypes  Plasmids Project name Project type Publication  \
# 0        NaN       NaN          NaN          NaN         NaN
# 1        NaN       NaN          NaN          NaN    21304645
#
#           Publication date Ref biomaterial Refseq accessions  \
# 0  2014-01-28T00:00:00.000             NaN         NC_009441
# 1  2009-02-19T00:00:00.000             NaN         NC_013162
#
#          Refseq category  Refseq cds Rel to oxygen  \
# 0  representative genome      5017.0           NaN
# 1  representative genome      2171.0           NaN
#
#      Relation to type material Release type        SRA accession  \
# 0  assembly from type material        Major                  NaN
# 1  assembly from type material        Major  SRR013476,SRR013477
#
#          Salinity Sample accession Sample name Sample type Seq rel date  \
# 0  Non-halophilic     SAMN02598357    CP000685         NaN   2007/05/01
# 1             NaN     SAMN00001911        FWCB         NaN   2009/08/26
#
#                                   Sequencing centers Sequencing depth  \
# 0                         DOE Joint Genome Institute              NaN
# 1  US DOE Joint Genome Institute (JGI-PGF)|DOE Jo...              NaN
#
#   Sequencing method Sequencing platform Sequencing platform resumed  \
# 0               NaN                 NaN                         NaN
# 1               NaN                 NaN                         NaN
#
#   Sequencing status Source mat ID  Species taxid Specific host Sporulation  \
# 0          complete           NaN          986.0           NaN          No
# 1          complete           NaN         1018.0           NaN          No
#
#        Strain Strain name alias Subject ID Submission model  \
# 0  ATCC 17061               NaN        NaN          Generic
# 1    DSM 7271               NaN        NaN          Generic
#
#   Submission package                                Submitter Subsrc note  \
# 0        Generic.1.0            US DOE Joint Genome Institute         NaN
# 1        Generic.1.0  US DOE Joint Genome Institute (JGI-PGF)         NaN
#
#   Supplier name     Taxid Temperature Temperature optimum Temperature range  \
# 0           NaN  376686.0         NaN               20-30        Mesophilic
# 1           NaN  521097.0         NaN               35-37        Mesophilic
#
#   Title Trophic level                             Type material Type strain  \
# 0   NaN           NaN  type strain of Flavobacterium johnsoniae         Yes
# 1   NaN           NaN    type strain of Capnocytophaga ochracea         Yes
#
#   Value Version status WGS master   pH Terrestrial_coordinates    MAG  \
# 0   NaN         latest        NaN  NaN                     NaN  False
# 1   NaN         latest        NaN  NaN                     NaN  False
#
#        Origin
# 0  Non_marine
# 1  Non_marine

# %% [markdown]
# ## Dataset metrics

# %%
dataset['Genus'].nunique()
# Out:
# 175

# %%
pd.to_datetime(dataset['Seq rel date']).dt.year.value_counts()
# Out:
# 2017.0    664
# 2020.0    479
# 2018.0    448
# 2019.0    423
# 2016.0    285
# 2014.0    132
# 2015.0    101
# 2013.0     80
# 2012.0     31
# 2011.0     15
# 2010.0      7
# 2009.0      6
# 2007.0      4
# 2006.0      4
# 2008.0      1
# Name: Seq rel date, dtype: int64

# %%
dataset[dataset["Family"]=="Flavobacteriaceae"]["Origin"].value_counts()
# Out:
# Marine          768
# Unclassified    667
# Non_marine      488
# Name: Origin, dtype: int64

# %%
dataset["Origin"].value_counts()/len(dataset.index)*100
# Out:
# Unclassified    36.926520
# Non_marine      33.494965
# Marine          29.541216
# Name: Origin, dtype: float64

# %%
dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>49)["Genus"].value_counts()
# Out:
# Flavobacterium      589
# Chryseobacterium    294
# Elizabethkingia     193
# Capnocytophaga       75
# Tenacibaculum        68
# Riemerella           59
# Polaribacter         57
# Winogradskyella      55
# Muricauda            53
# Myroides             50
# Name: Genus, dtype: int64

# %%
dataset_reduced = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"])["scaf_bp"].describe().round(1).reset_index()
dataset_reduced = dataset_reduced.sort_values(by=["Family","Genus"])
dataset_reduced.head()
# Out:
#          Genus             Family  count       mean        std        min  \
# 0  Aequorivita  Flavobacteriaceae   42.0  3200449.9   337441.8  2300656.0
# 1   Algibacter  Flavobacteriaceae    9.0  4651915.2   193665.3  4167837.0
# 3   Aquimarina  Flavobacteriaceae   39.0  5446681.9  1075942.7  2093196.0
# 4  Arenibacter  Flavobacteriaceae   22.0  5102481.5   531078.2  3985366.0
# 5       BACL21  Flavobacteriaceae   15.0  2271538.9   676488.7  1214042.0
#
#          25%        50%        75%        max
# 0  3081628.2  3193359.0  3327236.0  4042904.0
# 1  4638103.0  4705407.0  4707503.0  4816342.0
# 3  5125818.0  5838147.0  6131240.0  7041311.0
# 4  4728098.0  5260762.0  5472734.0  5857781.0
# 5  1772900.5  1915951.0  2881385.5  3240799.0

# %%
dataset_reduced2 = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family", "Origin"])["Origin"].count().to_frame()#
dataset_reduced2 = dataset_reduced2.rename(columns={"Origin":"Value"})#.reset_index()
dataset_reduced2.head()
# Out:
#                                             Value
# Genus       Family            Origin
# Aequorivita Flavobacteriaceae Marine           31
#                               Non_marine        5
#                               Unclassified      6
# Algibacter  Flavobacteriaceae Marine            3
#                               Non_marine        1

# %%
sns.set_style({'font.family': 'Arial'})
sns.set(style="whitegrid")
sns.set_context("paper", font_scale=1.5) 

plt.figure(figsize=(20,3))

g = sns.catplot(
    data=dataset_reduced, kind="bar", 
    x='Genus', hue="Family",dodge=False, legend_out=True, 
    y='mean', 
    height=6, # make the plot 7 units high
    aspect=2.5) # height is n times width

g._legend.set_bbox_to_anchor((1, 1))

g.map(plt.errorbar, "Genus", "mean", "std", ls='none', capsize=2, color="dimgrey")

plt.xlabel('Genomes grouped per Genus') 
plt.ylabel('Scaffold (bp)')

for ax in g.axes.ravel():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
    ax.margins(x=0.0055)
    
import matplotlib.lines as mlines
black_line=mlines.Line2D([], [], color='dimgrey', #marker='',
                          markersize=7, label='Standard deviation')
plt.legend(handles=[black_line], bbox_to_anchor=(0.89, 1), loc=(0,2), borderaxespad=0.);

#plt.show()    
ax = plt.gca()
g.savefig("genome_size.svg")

# %%
dataset_reduced = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"])["scaf_bp"].describe().round(1).reset_index()
dataset_reduced.head()
# Out:
#          Genus             Family  count       mean        std        min  \
# 0  Aequorivita  Flavobacteriaceae   42.0  3200449.9   337441.8  2300656.0
# 1   Algibacter  Flavobacteriaceae    9.0  4651915.2   193665.3  4167837.0
# 2    Apibacter      Weeksellaceae   21.0  2431255.1   312039.2  2255307.0
# 3   Aquimarina  Flavobacteriaceae   39.0  5446681.9  1075942.7  2093196.0
# 4  Arenibacter  Flavobacteriaceae   22.0  5102481.5   531078.2  3985366.0
#
#          25%        50%        75%        max
# 0  3081628.2  3193359.0  3327236.0  4042904.0
# 1  4638103.0  4705407.0  4707503.0  4816342.0
# 2  2275687.0  2326653.0  2331098.0  3296886.0
# 3  5125818.0  5838147.0  6131240.0  7041311.0
# 4  4728098.0  5260762.0  5472734.0  5857781.0

# %%
dataset_reduced = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby([ "Family"])["scaf_bp"].describe().round(1).reset_index()
dataset_reduced.head()
# Out:
#               Family   count       mean        std        min        25%  \
# 0  Flavobacteriaceae  1650.0  3517174.3  1123448.5   569462.0  2797355.0
# 1      Weeksellaceae   710.0  3929983.8   982223.8  1748436.0  3150627.0
#
#          50%        75%        max
# 0  3405979.0  4150103.0  7041311.0
# 1  4093812.0  4707221.5  6187872.0

# %%
dataset_reduced = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"])["scaf_bp"].describe().round(1).reset_index()

dataset_reduced2 = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"])["scaf_bp"].describe().round(1).reset_index()
dataset_reduced2 = dataset_reduced2.sort_values(by=["Family","Genus"])
dataset_reduced4 = dataset_reduced2[["Genus","Family","mean"]]
dataset_reduced4 = dataset_reduced4.pivot(index='Genus', columns='Family', values='mean')
dataset_reduced4 = dataset_reduced4.fillna(0).reset_index()
merge = pd.merge(dataset_reduced4, dataset_reduced, how="left", left_on="Genus", right_on="Genus")
merge = merge[["Genus", "Flavobacteriaceae", "Weeksellaceae", "Family"]]
merge = merge.sort_values(by=["Family","Genus"])
merge = merge.drop(columns="Family")
merge.head()
# Out:
#          Genus  Flavobacteriaceae  Weeksellaceae
# 0  Aequorivita          3200449.9            0.0
# 1   Algibacter          4651915.2            0.0
# 3   Aquimarina          5446681.9            0.0
# 4  Arenibacter          5102481.5            0.0
# 5       BACL21          2271538.9            0.0

# %%
dataset_reduced5 = dataset_reduced2[["Genus","Family","std"]]
dataset_reduced5.head()
# Out:
#          Genus             Family        std
# 0  Aequorivita  Flavobacteriaceae   337441.8
# 1   Algibacter  Flavobacteriaceae   193665.3
# 3   Aquimarina  Flavobacteriaceae  1075942.7
# 4  Arenibacter  Flavobacteriaceae   531078.2
# 5       BACL21  Flavobacteriaceae   676488.7

# %%
merge2 = pd.merge(merge, dataset_reduced5[["Genus","std"]], how="left", left_on="Genus", right_on="Genus")
merge2.head()
merge2.to_csv("Genome_size.csv")

# %%
merge2["Total"] = merge2["Flavobacteriaceae"] + merge2["Weeksellaceae"]
merge2["Total2"] = "0, 0, 0"
merge2.head()
# Out:
#          Genus  Flavobacteriaceae  Weeksellaceae        std      Total  \
# 0  Aequorivita          3200449.9            0.0   337441.8  3200449.9
# 1   Algibacter          4651915.2            0.0   193665.3  4651915.2
# 2   Aquimarina          5446681.9            0.0  1075942.7  5446681.9
# 3  Arenibacter          5102481.5            0.0   531078.2  5102481.5
# 4       BACL21          2271538.9            0.0   676488.7  2271538.9
#
#     Total2
# 0  0, 0, 0
# 1  0, 0, 0
# 2  0, 0, 0
# 3  0, 0, 0
# 4  0, 0, 0

# %%
dataset_reduced = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"])["scaf_bp"].describe().round(1).reset_index()

count = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"])["scaf_bp"].count().reset_index()
count = count.rename(columns={"scaf_bp":"count"})#.reset_index()
count = count.sort_values(by=["Family","Genus"])

#count= count.drop(columns="Family")
count.head()
# Out:
#          Genus             Family  count
# 0  Aequorivita  Flavobacteriaceae     42
# 1   Algibacter  Flavobacteriaceae      9
# 3   Aquimarina  Flavobacteriaceae     39
# 4  Arenibacter  Flavobacteriaceae     22
# 5       BACL21  Flavobacteriaceae     15

# %%
sns.set_style({'font.family': 'Arial'})
sns.set(style="darkgrid")
sns.set_context("paper", font_scale=1.5) 

my_colors=["#505050","#505050"]

ax = count.plot(kind='bar', x="Genus" ,figsize=(20,3), stacked=True, legend=False, color=my_colors)#, yerr="std")#, error_kw=dict(ecolor='black',elinewidth=0.5, barsabove=True))
ax.set(yscale="log")

for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.0f}'.format(y), (x.mean(),y),ha='center', va='bottom', fontsize=10) # set the alignment of the text

ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.set(ylabel='Number of genomes (log)')
    
fig = ax.get_figure()

fig.savefig("Genome_count_log.svg", dpi=300, bbox_inches='tight')

# %%
dataset_reduced2 = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family", "Origin"])["Origin"].count().to_frame()#
dataset_reduced2 = dataset_reduced2.rename(columns={"Origin":"Value"})#.reset_index()
dataset_reduced2 = dataset_reduced2.unstack('Origin')#.droplevel(level=0)
dataset_reduced2 = dataset_reduced2.fillna(0)

dataset_reduced2.columns = dataset_reduced2.columns.droplevel()

dataset_reduced2 = dataset_reduced2.reset_index()#.drop_index()
dataset_reduced2["Total"] = dataset_reduced2["Marine"] + dataset_reduced2["Non_marine"] + dataset_reduced2["Unclassified"]
dataset_reduced3 = dataset_reduced2.copy()
dataset_reduced3["Marine %"] = dataset_reduced3["Marine"] / dataset_reduced3["Total"] *100
dataset_reduced3["Non_marine %"] = dataset_reduced3["Non_marine"] / dataset_reduced3["Total"] *100
dataset_reduced3["Unclassified %"] = dataset_reduced3["Unclassified"] / dataset_reduced3["Total"] *100
dataset_reduced3 = dataset_reduced3.drop(columns=["Marine", "Non_marine","Unclassified","Total"])
dataset_reduced3 = dataset_reduced3.sort_values(by=["Family","Genus"])
dataset_reduced3 = dataset_reduced3.rename(columns={"Marine %":"Marine","Non_marine %":"Non_marine", "Unclassified %":"Unclassified"})#.reset_index()

dataset_reduced3.head()
# Out:
# Origin        Genus             Family     Marine  Non_marine  Unclassified
# 0       Aequorivita  Flavobacteriaceae  73.809524   11.904762     14.285714
# 1        Algibacter  Flavobacteriaceae  33.333333   11.111111     55.555556
# 3        Aquimarina  Flavobacteriaceae  46.153846    7.692308     46.153846
# 4       Arenibacter  Flavobacteriaceae  59.090909    9.090909     31.818182
# 5            BACL21  Flavobacteriaceae  73.333333   20.000000      6.666667

# %%
from  matplotlib.ticker import PercentFormatter

sns.set_style({'font.family': 'Arial'})
sns.set(style="white")
sns.set_context("paper", font_scale=1.5) 

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

my_colors=["#101070","#2f7e2f","#cbcccb"]

ax = dataset_reduced3.plot(kind='bar', x="Genus",stacked=True, figsize=(20,6), legend=False, color=my_colors)

ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.yaxis.set_major_formatter(PercentFormatter())
#ax.ylabel('',  color="black")

fig = ax.get_figure()
fig.savefig("Distribution_regarding_origin.pdf", dpi=300, bbox_inches='tight')

# %% [markdown]
# ## Sort by P ratio:

# %%
l = ['Zunongwangia', 'Algibacter', 'Leeuwenhoekiella', 'Euzebyella', 'CG1-02-35-72', 'Arenibacter', 'Capnocytophaga', 'Polaribacter', 'UBA8316', 'BACL21', 'Ornithobacterium', 'Jejuia', 'Cellulophaga', 'UBA3537', 'Lacinutrix', 'Gillisia', 'Flavobacterium', 'Salegentibacter', 'Olleya', 'Gramella', 'Mesonia', 'Lutibacter', 'Nonlabens', 'UBA7446', 'CG2-30-34-30', 'UBA724', 'UBA6231', 'Gelidibacter', 'Epilithonimonas', 'Winogradskyella', 'Elizabethkingia', 'Croceivirga', 'Dokdonia', 'Maribacter', 'Muricauda', 'Empedobacter', 'Marixanthomonas', 'MAG-120531', 'Xanthomarina', 'Chryseobacterium', 'Aequorivita', 'Psychroserpens', 'Psychroflexus', 'Aquimarina', 'Kordia', 'Kaistella', 'Marinirhabdus', 'MED-G14', 'Riemerella', 'Uncl. Flavobacteriaceae', 'MS024-2A', 'MAG-121220-bin8', 'SHLJ01', 'Muriicola', 'Planobacterium', 'Apibacter', 'UBA11891', 'Tenacibaculum', 'MED-G11', 'Myroides']

# Create the dictionary that defines the order for sorting
sorterIndex = dict(zip(l, range(len(l))))

# Generate a rank column that will be used to sort
# the dataframe numerically
dataset_reduced3['Genus2'] = dataset_reduced3['Genus'].map(sorterIndex)

dataset_reduced3_sorted = dataset_reduced3.sort_values(by="Genus2")

# %%
from  matplotlib.ticker import PercentFormatter

sns.set_style({'font.family': 'Arial'})
sns.set(style="white")
sns.set_context("paper", font_scale=1.5) 

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

my_colors=["#101070","#2f7e2f","#cbcccb"]

ax = dataset_reduced3_sorted.drop(columns="Genus2").plot(kind='bar', x="Genus",stacked=True, figsize=(20,6), legend=False, color=my_colors)

ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.yaxis.set_major_formatter(PercentFormatter())
#ax.ylabel('',  color="black")

fig = ax.get_figure()
#fig.savefig("Distribution_regarding_origin.pdf", dpi=300, bbox_inches='tight')

# %%
dataset_reduced2 = dataset.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family", "MAG"])["MAG"].count().to_frame()
dataset_reduced2 = dataset_reduced2.rename(columns={"MAG":"Value"})#.reset_index()
dataset_reduced2 = dataset_reduced2.unstack('MAG')#.droplevel(level=0)
dataset_reduced2 = dataset_reduced2.fillna(0)

dataset_reduced2.columns = dataset_reduced2.columns.droplevel()
dataset_reduced2 = dataset_reduced2.reset_index()#.drop_index()
dataset_reduced2 = dataset_reduced2.rename(columns={False:"Cultivated genome", True:"MAG"})#.reset_index()

dataset_reduced3 = dataset_reduced2.copy()
dataset_reduced3["Total"] = dataset_reduced3["MAG"] + dataset_reduced3["Cultivated genome"]
dataset_reduced3["MAG %"] = dataset_reduced3["MAG"] / dataset_reduced3["Total"] *100
dataset_reduced3["Cultivated genome %"] = dataset_reduced3["Cultivated genome"] / dataset_reduced3["Total"] *100
dataset_reduced3 = dataset_reduced3.drop(columns=["MAG", "Cultivated genome","Total"])
dataset_reduced3 = dataset_reduced3.sort_values(by=["Family","Genus"])
dataset_reduced3 = dataset_reduced3.rename(columns={"MAG %":"MAG", "Cultivated genome %":"Cultivated \ngenome"})#.reset_index()

dataset_reduced3.head()
# Out:
# MAG        Genus             Family         MAG  Cultivated \ngenome
# 0    Aequorivita  Flavobacteriaceae   61.904762            38.095238
# 1     Algibacter  Flavobacteriaceae    0.000000           100.000000
# 3     Aquimarina  Flavobacteriaceae    5.128205            94.871795
# 4    Arenibacter  Flavobacteriaceae   13.636364            86.363636
# 5         BACL21  Flavobacteriaceae  100.000000             0.000000

# %%
from  matplotlib.ticker import PercentFormatter

sns.set_style({'font.family': 'Arial'})
sns.set(style="white")
sns.set_context("paper", font_scale=1.5) 


my_colors=["#BA0303","#FCCE38"]

ax = dataset_reduced3.plot(kind='bar', x="Genus",stacked=True, figsize=(20,6), legend=False, color=my_colors)

ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.yaxis.set_major_formatter(PercentFormatter())
#ax.ylabel('',  color="black")

fig = ax.get_figure()
fig.savefig("Distribution_regarding_genome_assembly.pdf", dpi=300, bbox_inches='tight')

# %%
l = ['Zunongwangia', 'Algibacter', 'Leeuwenhoekiella', 'Euzebyella', 'CG1-02-35-72', 'Arenibacter', 'Capnocytophaga', 'Polaribacter', 'UBA8316', 'BACL21', 'Ornithobacterium', 'Jejuia', 'Cellulophaga', 'UBA3537', 'Lacinutrix', 'Gillisia', 'Flavobacterium', 'Salegentibacter', 'Olleya', 'Gramella', 'Mesonia', 'Lutibacter', 'Nonlabens', 'UBA7446', 'CG2-30-34-30', 'UBA724', 'UBA6231', 'Gelidibacter', 'Epilithonimonas', 'Winogradskyella', 'Elizabethkingia', 'Croceivirga', 'Dokdonia', 'Maribacter', 'Muricauda', 'Empedobacter', 'Marixanthomonas', 'MAG-120531', 'Xanthomarina', 'Chryseobacterium', 'Aequorivita', 'Psychroserpens', 'Psychroflexus', 'Aquimarina', 'Kordia', 'Kaistella', 'Marinirhabdus', 'MED-G14', 'Riemerella', 'Uncl. Flavobacteriaceae', 'MS024-2A', 'MAG-121220-bin8', 'SHLJ01', 'Muriicola', 'Planobacterium', 'Apibacter', 'UBA11891', 'Tenacibaculum', 'MED-G11', 'Myroides']

# Create the dictionary that defines the order for sorting
sorterIndex = dict(zip(l, range(len(l))))

# Generate a rank column that will be used to sort
# the dataframe numerically
dataset_reduced3['Genus2'] = dataset_reduced3['Genus'].map(sorterIndex)

dataset_reduced3_sorted = dataset_reduced3.sort_values(by="Genus2")

# %%
from  matplotlib.ticker import PercentFormatter

sns.set_style({'font.family': 'Arial'})
sns.set(style="white")
sns.set_context("paper", font_scale=1.5) 


my_colors=["#BA0303","#FCCE38"]

ax = dataset_reduced3_sorted.drop(columns="Genus2").plot(kind='bar', x="Genus",stacked=True, figsize=(20,6), legend=False, color=my_colors)

ax.legend(bbox_to_anchor=(1, 1), loc='upper left')
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')
ax.yaxis.set_major_formatter(PercentFormatter())
#ax.ylabel('',  color="black")

fig = ax.get_figure()
#fig.savefig("Distribution_regarding_genome_assembly.pdf", dpi=300, bbox_inches='tight')

# %%
dataset_reduced3[dataset_reduced3["Cultivated \ngenome"] <= 30]
# Out:
# MAG            Genus             Family         MAG  Cultivated \ngenome  \
# 5             BACL21  Flavobacteriaceae  100.000000             0.000000
# 6       CG1-02-35-72  Flavobacteriaceae  100.000000             0.000000
# 7       CG2-30-34-30  Flavobacteriaceae  100.000000             0.000000
# 16        Euzebyella  Flavobacteriaceae   88.888889            11.111111
# 27        MAG-120531  Flavobacteriaceae   96.551724             3.448276
# 28   MAG-121220-bin8  Flavobacteriaceae  100.000000             0.000000
# 29           MED-G11  Flavobacteriaceae  100.000000             0.000000
# 30           MED-G14  Flavobacteriaceae  100.000000             0.000000
# 31          MS024-2A  Flavobacteriaceae   94.736842             5.263158
# 33     Marinirhabdus  Flavobacteriaceae   85.714286            14.285714
# 34   Marixanthomonas  Flavobacteriaceae   77.777778            22.222222
# 37         Muriicola  Flavobacteriaceae   75.000000            25.000000
# 47            SHLJ01  Flavobacteriaceae  100.000000             0.000000
# 50          UBA11891  Flavobacteriaceae  100.000000             0.000000
# 51           UBA3537  Flavobacteriaceae   91.666667             8.333333
# 52           UBA6231  Flavobacteriaceae   92.307692             7.692308
# 53            UBA724  Flavobacteriaceae  100.000000             0.000000
# 54           UBA7446  Flavobacteriaceae  100.000000             0.000000
# 55           UBA8316  Flavobacteriaceae  100.000000             0.000000
# 59      Zunongwangia  Flavobacteriaceae   76.923077            23.076923
# 14      Empedobacter      Weeksellaceae   72.727273            27.272727
#
# MAG  Genus2
# 5         9
# 6         4
# 7        24
# 16        3
# 27       37
# 28       51
# 29       58
# 30       47
# 31       50
# 33       46
# 34       36
# 37       53
# 47       52
# 50       56
# 51       13
# 52       26
# 53       25
# 54       23
# 55        8
# 59        0
# 14       35

# %%
dataset_reduced3[dataset_reduced3["Cultivated \ngenome"] <= 0]
# Out:
# MAG            Genus             Family    MAG  Cultivated \ngenome  Genus2
# 5             BACL21  Flavobacteriaceae  100.0                  0.0       9
# 6       CG1-02-35-72  Flavobacteriaceae  100.0                  0.0       4
# 7       CG2-30-34-30  Flavobacteriaceae  100.0                  0.0      24
# 28   MAG-121220-bin8  Flavobacteriaceae  100.0                  0.0      51
# 29           MED-G11  Flavobacteriaceae  100.0                  0.0      58
# 30           MED-G14  Flavobacteriaceae  100.0                  0.0      47
# 47            SHLJ01  Flavobacteriaceae  100.0                  0.0      52
# 50          UBA11891  Flavobacteriaceae  100.0                  0.0      56
# 53            UBA724  Flavobacteriaceae  100.0                  0.0      25
# 54           UBA7446  Flavobacteriaceae  100.0                  0.0      23
# 55           UBA8316  Flavobacteriaceae  100.0                  0.0       8

# %% [markdown]
# 11 genus 100% MAGs
