# %% [markdown]
# # BGC analysis

# %% [markdown]
# Author: Sandra Godinho Silva \
# Creation date: 2/10/2020 \
# Version: 0.3

# %%
#import libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 1000)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# ## Metadata

# %%
metadata = pd.read_csv("/home/gomes/silva2/Figure_1_Dataset/All_info.csv")
metadata.head(2)
# Out:
#   Assembly accession                             Bin_Id  \
# 0    GCA_000016645.1  GCA_000016645.1_ASM1664v1_genomic
# 1    GCA_000023285.1  GCA_000023285.1_ASM2328v1_genomic
#
#                    Marker lineage  Completeness  Contamination  \
# 0  f__Flavobacteriaceae (UID2817)         99.65           0.14
# 1      p__Bacteroidetes (UID2605)        100.00           0.00
#
#    Strain_heterogeneity  Quality_score  \
# 0                   0.0          98.95
# 1                   0.0         100.00
#
#                                       classification    Domain         Phyla  \
# 0  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
#
#          Class             Order             Family           Genus  \
# 0  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Flavobacterium
# 1  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Capnocytophaga
#
#                      Species  n_scaffolds  n_contigs  scaf_bp  contig_bp  \
# 0  Flavobacterium johnsoniae            1          1  6096872    6096872
# 1    Capnocytophaga ochracea            1          1  2612925    2612925
#
#    gap_pct  scaf_N50  scaf_L50  ctg_N50  ctg_L50  scaf_N90  scaf_L90  ctg_N90  \
# 0      0.0         1   6096872        1  6096872         1   6096872        1
# 1      0.0         1   2612925        1  2612925         1   2612925        1
#
#    ctg_L90  scaf_max  ctg_max  scaf_n_gt50K  scaf_pct_gt50K   gc_avg  gc_std  \
# 0  6096872   6096872  6096872             1           100.0  0.34113     0.0
# 1  2612925   2612925  2612925             1           100.0  0.39588     0.0
#
#   Classification_quality  orfs  pfam    ko   cog  cazymes  Orfs_anno_pfam%  \
# 0                   High  5192  3948  1843  3127      244        76.040062
# 1                   High  2182  1720   907  1353       88        78.826764
#
#    Orfs_anno_ko%  Orfs_anno_cog%  Orfs_anno_cazymes%   ASM name Alias  \
# 0      35.496918       60.227273            4.699538  ASM1664v1   NaN
# 1      41.567369       62.007333            4.032997  ASM2328v1   NaN
#
#   Altitude Anonymized name Arrayexpress species Arrayexpress strain or line  \
# 0      NaN             NaN                  NaN                         NaN
# 1      NaN             NaN                  NaN                         NaN
#
#     Assembly level Assembly method Assembly method resumed  \
# 0  Complete Genome             NaN                     NaN
# 1  Complete Genome             NaN                     NaN
#
#   Biomaterial provider Bioproject accession Biosample accession  \
# 0                  NaN           PRJNA16082        SAMN02598357
# 1                  NaN           PRJNA29403        SAMN00001911
#
#   Biosample model                                    Biosample title  \
# 0             NaN        Sample from Flavobacterium johnsoniae UW101
# 1             NaN  Generic sample from Capnocytophaga ochracea DS...
#
#   Biotic relationship Body sample site Cell shape Collected by  \
# 0                 NaN              NaN        Rod          NaN
# 1                 NaN              NaN        Rod          NaN
#
#   Collection date                                  Comment paragraph  \
# 0             NaN  Flavobacterium johnsoniae ATCC 17061. Flavobac...
# 1             NaN                   Capnocytophaga ochracea DSM 7271
#
#         Completion date Contact email Contact lab  Contigs Country  \
# 0  2007-05-01T00:00:00Z           NaN         NaN      1.0     NaN
# 1  2009-04-30T00:00:00Z           NaN         NaN      1.0     NaN
#
#   Culture collection Depth Derived from Description Disease ENA checklist  \
# 0         ATCC 17061   NaN          NaN         NaN     NaN           NaN
# 1           DSM 7271   NaN          NaN         NaN     NaN           NaN
#
#   ENA-first-public ENA-last-update Elevation Env biome Env broad scale  \
# 0              NaN             NaN       NaN       NaN             NaN
# 1              NaN             NaN       NaN       NaN             NaN
#
#   Env feature Env local scale Env material Env medium Environment  \
# 0         NaN             NaN          NaN        NaN         NaN
# 1         NaN             NaN          NaN        NaN         NaN
#
#   Environmental sample Estimated size Excluded from refseq FDA cvm ID  \
# 0                  NaN            NaN                  NaN        NaN
# 1                  NaN            NaN                  NaN        NaN
#
#   Finishing strategy (depth of coverage) First name  \
# 0                                    NaN        NaN
# 1                                    NaN        NaN
#
#                                             Ftp path GOLD stamp ID  \
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...           NaN
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/000...           NaN
#
#    Gbrs paired ASM Genbank accessions Gene calling method  \
# 0  GCF_000016645.1           CP000685                 NaN
# 1  GCF_000023285.1           CP001632                 NaN
#
#                         Genome name Genome quality flags Genome rep  \
# 0   Flavobacterium johnsoniae UW101                  NaN       Full
# 1  Capnocytophaga ochracea DSM 7271                  NaN       Full
#
#   Genome status Genotype      Geographic location Geographic location (city)  \
# 0      Complete      NaN  United Kingdom: England                    England
# 1      Complete      NaN                      NaN                        NaN
#
#   Geographic location (country or region) Gram stain          Habitat  \
# 0                          United Kingdom        NaN         Multiple
# 1                                     NaN        NaN  Host-associated
#
#                   Host Host age Host disease Host disease outcome Host gender  \
# 0                  NaN      NaN          NaN                  NaN         NaN
# 1  Human, homo sapiens      NaN          NaN                  NaN         NaN
#
#   Host health            Host name  Host resumed Host scientific name  \
# 0         NaN                  NaN           NaN                  NaN
# 1         NaN  Human, Homo sapiens  Homo sapiens                  NaN
#
#   Host sex  Host taxid Host tissue sampled INSDC center alias  \
# 0      NaN         NaN                 NaN                NaN
# 1      NaN         NaN                 NaN                NaN
#
#   INSDC center name INSDC first public INSDC last update INSDC status  \
# 0               NaN                NaN               NaN          NaN
# 1               NaN                NaN               NaN          NaN
#
#   Identification method Identified by        Infraspecific name  \
# 0                   NaN           NaN  strain=UW101; ATCC 17061
# 1                   NaN           NaN           strain=DSM 7271
#
#   Investigation type Isol growth condt Isolate  \
# 0                NaN               NaN     NaN
# 1                NaN               NaN     NaN
#
#                                   Isolation comments Isolation country  \
# 0  isolated from soil in England and is the type ...    United Kingdom
# 1                isolated from the human oral cavity               NaN
#
#   Isolation site       Isolation source Last name Latitude Locus tag prefix  \
# 0            NaN                   soil       NaN      NaN              NaN
# 1            NaN  the human oral cavity       NaN      NaN              NaN
#
#   Longitude MLST Mapping method and version Material Metagenome source  \
# 0       NaN  NaN                        NaN      NaN               NaN
# 1       NaN  NaN                        NaN      NaN               NaN
#
#   Misc param Misc param: hmp supersite Motility  \
# 0        NaN                       NaN      Yes
# 1        NaN                       NaN      Yes
#
#                                                 Name  Ncbi taxon ID Note  \
# 0                                               NCBI       376686.0  NaN
# 1  Joint Genome Institute, U.S. Department of Energy       521097.0  NaN
#
#                            Organism                     Organism name  \
# 0   Flavobacterium johnsoniae UW101   Flavobacterium johnsoniae UW101
# 1  Capnocytophaga ochracea DSM 7271  Capnocytophaga ochracea DSM 7271
#
#   Other clinical Other environmental Oxygen requirement Paired ASM comp  \
# 0            NaN                 NaN            Aerobic       identical
# 1            NaN                 NaN        Facultative       identical
#
#   Phenotypes  Plasmids Project name Project type Publication  \
# 0        NaN       NaN          NaN          NaN         NaN
# 1        NaN       NaN          NaN          NaN    21304645
#
#           Publication date Ref biomaterial Refseq accessions  \
# 0  2014-01-28T00:00:00.000             NaN         NC_009441
# 1  2009-02-19T00:00:00.000             NaN         NC_013162
#
#          Refseq category  Refseq cds Rel to oxygen  \
# 0  representative genome      5017.0           NaN
# 1  representative genome      2171.0           NaN
#
#      Relation to type material Release type        SRA accession  \
# 0  assembly from type material        Major                  NaN
# 1  assembly from type material        Major  SRR013476,SRR013477
#
#          Salinity Sample accession Sample name Sample type Seq rel date  \
# 0  Non-halophilic     SAMN02598357    CP000685         NaN   2007/05/01
# 1             NaN     SAMN00001911        FWCB         NaN   2009/08/26
#
#                                   Sequencing centers Sequencing depth  \
# 0                         DOE Joint Genome Institute              NaN
# 1  US DOE Joint Genome Institute (JGI-PGF)|DOE Jo...              NaN
#
#   Sequencing method Sequencing platform Sequencing platform resumed  \
# 0               NaN                 NaN                         NaN
# 1               NaN                 NaN                         NaN
#
#   Sequencing status Source mat ID  Species taxid Specific host Sporulation  \
# 0          complete           NaN          986.0           NaN          No
# 1          complete           NaN         1018.0           NaN          No
#
#        Strain Strain name alias Subject ID Submission model  \
# 0  ATCC 17061               NaN        NaN          Generic
# 1    DSM 7271               NaN        NaN          Generic
#
#   Submission package                                Submitter Subsrc note  \
# 0        Generic.1.0            US DOE Joint Genome Institute         NaN
# 1        Generic.1.0  US DOE Joint Genome Institute (JGI-PGF)         NaN
#
#   Supplier name     Taxid Temperature Temperature optimum Temperature range  \
# 0           NaN  376686.0         NaN               20-30        Mesophilic
# 1           NaN  521097.0         NaN               35-37        Mesophilic
#
#   Title Trophic level                             Type material Type strain  \
# 0   NaN           NaN  type strain of Flavobacterium johnsoniae         Yes
# 1   NaN           NaN    type strain of Capnocytophaga ochracea         Yes
#
#   Value Version status WGS master   pH Terrestrial_coordinates    MAG  \
# 0   NaN         latest        NaN  NaN                     NaN  False
# 1   NaN         latest        NaN  NaN                     NaN  False
#
#        Origin
# 0  Non_marine
# 1  Non_marine

# %% [markdown]
# ## Number BGCs per type

# %%
bgc = pd.read_csv("/home/gomes/silva2/3_Annotation/antismash_results/BGCs_resumed.csv")
bgc = bgc.set_index("index").T
bgc["Nr_BGCs"] = bgc.sum(axis=1)
bgc.head()
# Out:
# index            NRPS  NRPS_PKS_hybrid  NRPS_other  Others  PKSI  PKSIII  \
# GCA_002831645.1     0                0           0       1     0       1
# GCA_001971785.1     0                0           0       0     0       0
# GCA_002951395.1     0                0           0       0     0       0
# GCA_903969135.1     1                0           0       1     0       0
# GCA_009664855.1     0                0           0       2     0       1
#
# index            PKS_other  RiPPs  Siderophore  terpene  transAT_PSK  Nr_BGCs
# GCA_002831645.1          0      1            0        1            0        4
# GCA_001971785.1          0      1            0        1            0        2
# GCA_002951395.1          0      0            1        1            0        2
# GCA_903969135.1          1      3            1        1            0        8
# GCA_009664855.1          0      2            0        2            0        7

# %% [markdown]
# ## All information about each BGC

# %%
bgc_info = pd.read_csv("/home/gomes/silva2/3_Annotation/antismash_results/all_BGC_info.csv")
bgc_info = bgc_info.rename(columns={"Most_similar_known_ cluster":"Most_similar_known_cluster"})
bgc_info.head(2)
# Out:
#             Genome   Region_Type    antiSMASH_classif new_classif       From  \
# 0  GCA_002831645.1  Region&nbsp1                T3PKS      PKSIII   582350.0
# 1  GCA_002831645.1  Region&nbsp2  terpene,bacteriocin      Others  1879449.0
#
#         To  Size(bp) Most_similar_known_cluster Most_similar_classif  \
# 0   623402   41052.0                        NaN                  NaN
# 1  1909353   29904.0                        NaN                  NaN
#
#   Similarity                     Correct_name
# 0        NaN  GCA_002831645_contig1.region001
# 1        NaN  GCA_002831645_contig1.region002

# %%
len(bgc_info)
# Out:
# 9330

# %%
bgc_known = bgc_info[bgc_info["Most_similar_classif"].notnull()]
bgc_known.head(2)
# Out:
#             Genome   Region_Type antiSMASH_classif new_classif       From  \
# 2  GCA_002831645.1  Region&nbsp3           terpene     terpene  2137564.0
# 5  GCA_001971785.1  Region&nbsp2           terpene     terpene  2834169.0
#
#         To  Size(bp) Most_similar_known_cluster Most_similar_classif  \
# 2  2160010   22446.0                 carotenoid              Terpene
# 5  2855008   20839.0                 carotenoid              Terpene
#
#   Similarity                     Correct_name
# 2        28%  GCA_002831645_contig1.region003
# 5        28%  GCA_001971785_contig1.region002

# %%
len(bgc_known)
# Out:
# 4344

# %% [markdown]
# ### Merge with metadata:

# %%
bgc_known_metadata = pd.merge(bgc_known, metadata, how="left", left_on="Genome", right_on="Assembly accession")
#bgc_known_metadata = merged.set_index("Genome")
bgc_known_metadata.head(2)
# Out:
#             Genome   Region_Type antiSMASH_classif new_classif       From  \
# 0  GCA_002831645.1  Region&nbsp3           terpene     terpene  2137564.0
# 1  GCA_001971785.1  Region&nbsp2           terpene     terpene  2834169.0
#
#         To  Size(bp) Most_similar_known_cluster Most_similar_classif  \
# 0  2160010   22446.0                 carotenoid              Terpene
# 1  2855008   20839.0                 carotenoid              Terpene
#
#   Similarity                     Correct_name Assembly accession  \
# 0        28%  GCA_002831645_contig1.region003    GCA_002831645.1
# 1        28%  GCA_001971785_contig1.region002    GCA_001971785.1
#
#                                 Bin_Id         Marker lineage  Completeness  \
# 0  GCA_002831645.1_ASM283164v1_genomic  s__algicola (UID2846)         99.67
# 1  GCA_001971785.1_ASM197178v1_genomic  s__algicola (UID2846)         98.35
#
#    Contamination  Strain_heterogeneity  Quality_score  \
# 0           0.33                   0.0          98.02
# 1           1.25                   0.0          92.10
#
#                                       classification    Domain         Phyla  \
# 0  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
# 1  d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...  Bacteria  Bacteroidota
#
#          Class             Order             Family           Genus  \
# 0  Bacteroidia  Flavobacteriales  Flavobacteriaceae          Olleya
# 1  Bacteroidia  Flavobacteriales  Flavobacteriaceae  Seonamhaeicola
#
#                       Species  n_scaffolds  n_contigs  scaf_bp  contig_bp  \
# 0          Olleya sp002831645            1          1  4314320    4314320
# 1  Seonamhaeicola sp001971785            1          1  3752836    3752836
#
#    gap_pct  scaf_N50  scaf_L50  ctg_N50  ctg_L50  scaf_N90  scaf_L90  ctg_N90  \
# 0      0.0         1   4314320        1  4314320         1   4314320        1
# 1      0.0         1   3752836        1  3752836         1   3752836        1
#
#    ctg_L90  scaf_max  ctg_max  scaf_n_gt50K  scaf_pct_gt50K   gc_avg  gc_std  \
# 0  4314320   4314320  4314320             1           100.0  0.32759     0.0
# 1  3752836   3752836  3752836             1           100.0  0.32262     0.0
#
#   Classification_quality  orfs  pfam    ko   cog  cazymes  Orfs_anno_pfam%  \
# 0                   High  3835  2862  1368  2230       90        74.628422
# 1                   High  3259  2629  1367  2134      140        80.668917
#
#    Orfs_anno_ko%  Orfs_anno_cog%  Orfs_anno_cazymes%     ASM name Alias  \
# 0      35.671447       58.148631            2.346806  ASM283164v1   NaN
# 1      41.945382       65.480209            4.295796  ASM197178v1   NaN
#
#   Altitude Anonymized name Arrayexpress species Arrayexpress strain or line  \
# 0      NaN             NaN                  NaN                         NaN
# 1      NaN             NaN                  NaN                         NaN
#
#     Assembly level     Assembly method Assembly method resumed  \
# 0  Complete Genome  Unicycler v. 0.3.1      Unicycler v. 0.3.1
# 1  Complete Genome                 NaN                     NaN
#
#   Biomaterial provider Bioproject accession Biosample accession  \
# 0                  NaN          PRJNA420923        SAMN08125748
# 1                  NaN          PRJNA362242        SAMN06236790
#
#   Biosample model                                    Biosample title  \
# 0             NaN  MIGS Cultured Bacterial/Archaeal sample from O...
# 1             NaN                                                NaN
#
#   Biotic relationship Body sample site Cell shape Collected by  \
# 0                 NaN              NaN        NaN          NaN
# 1                 NaN              NaN        NaN          NaN
#
#   Collection date            Comment paragraph       Completion date  \
# 0            2014  Keywords: GSC:MIxS;MIGS:5.0  2017-12-11T00:00:00Z
# 1             NaN                          NaN                   NaN
#
#         Contact email Contact lab  Contigs Country Culture collection Depth  \
# 0  cryomics@gmail.com         NaN      1.0     NaN                NaN     0
# 1                 NaN         NaN      NaN     NaN                NaN   NaN
#
#   Derived from Description Disease ENA checklist ENA-first-public  \
# 0          NaN         NaN     NaN           NaN              NaN
# 1          NaN         NaN     NaN           NaN              NaN
#
#   ENA-last-update Elevation     Env biome Env broad scale   Env feature  \
# 0             NaN       NaN  marine biome             NaN  sea ice floe
# 1             NaN       NaN           NaN             NaN           NaN
#
#   Env local scale Env material Env medium Environment Environmental sample  \
# 0             NaN      sea ice        NaN         NaN                  NaN
# 1             NaN          NaN        NaN         NaN                  NaN
#
#   Estimated size Excluded from refseq FDA cvm ID  \
# 0            NaN                  NaN        NaN
# 1            NaN                  NaN        NaN
#
#   Finishing strategy (depth of coverage) First name  \
# 0                                    NaN       Eric
# 1                                    NaN        NaN
#
#                                             Ftp path GOLD stamp ID  \
# 0  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002...           NaN
# 1  ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001...           NaN
#
#    Gbrs paired ASM Genbank accessions Gene calling method         Genome name  \
# 0  GCF_002831645.1           CP025117                 NaN  Olleya sp. Bg11-27
# 1  GCF_001971785.1                NaN                 NaN                 NaN
#
#   Genome quality flags Genome rep Genome status Genotype  \
# 0                  NaN       Full      Complete      NaN
# 1                  NaN       Full           NaN      NaN
#
#               Geographic location Geographic location (city)  \
# 0  USA: near Point Barrow, Alaska  near Point Barrow, Alaska
# 1                             NaN                        NaN
#
#   Geographic location (country or region) Gram stain Habitat Host Host age  \
# 0                                     USA        NaN     NaN  NaN      NaN
# 1                                     NaN        NaN     NaN  NaN      NaN
#
#   Host disease Host disease outcome Host gender Host health Host name  \
# 0          NaN                  NaN         NaN         NaN       NaN
# 1          NaN                  NaN         NaN         NaN       NaN
#
#   Host resumed Host scientific name Host sex  Host taxid Host tissue sampled  \
# 0          NaN                  NaN      NaN         NaN                 NaN
# 1          NaN                  NaN      NaN         NaN                 NaN
#
#   INSDC center alias INSDC center name INSDC first public INSDC last update  \
# 0                NaN               NaN                NaN               NaN
# 1                NaN               NaN                NaN               NaN
#
#   INSDC status Identification method Identified by Infraspecific name  \
# 0          NaN                   NaN           NaN     strain=Bg11-27
# 1          NaN                   NaN           NaN        strain=S2-3
#
#   Investigation type    Isol growth condt Isolate Isolation comments  \
# 0                NaN  Bg11 medium, 4deg C     NaN                NaN
# 1                NaN                  NaN     NaN                NaN
#
#   Isolation country Isolation site Isolation source Last name Latitude  \
# 0     United States            NaN          sea ice   Collins     71.3
# 1               NaN            NaN              NaN       NaN      NaN
#
#   Locus tag prefix Longitude MLST Mapping method and version Material  \
# 0              NaN      -157  NaN                        NaN      NaN
# 1              NaN       NaN  NaN                        NaN      NaN
#
#   Metagenome source Misc param Misc param: hmp supersite Motility  \
# 0               NaN        NaN                       NaN      NaN
# 1               NaN        NaN                       NaN      NaN
#
#                              Name  Ncbi taxon ID Note            Organism  \
# 0  University of Alaska Fairbanks      2058135.0  NaN  Olleya sp. Bg11-27
# 1                             NaN            NaN  NaN                 NaN
#
#              Organism name Other clinical     Other environmental  \
# 0       Olleya sp. Bg11-27            NaN  env_biome:marine biome
# 1  Seonamhaeicola sp. S2-3            NaN                     NaN
#
#   Oxygen requirement Paired ASM comp Phenotypes  Plasmids Project name  \
# 0                NaN       identical        NaN       NaN          NaN
# 1                NaN       identical        NaN       NaN          NaN
#
#   Project type Publication         Publication date Ref biomaterial  \
# 0          NaN         NaN  2017-12-04T00:00:00.000             NaN
# 1          NaN         NaN                      NaN             NaN
#
#   Refseq accessions Refseq category  Refseq cds Rel to oxygen  \
# 0               NaN             NaN      3803.0           NaN
# 1               NaN             NaN         NaN           NaN
#
#   Relation to type material Release type SRA accession Salinity  \
# 0                       NaN        Major           NaN      NaN
# 1                       NaN        Major           NaN      NaN
#
#   Sample accession     Sample name Sample type Seq rel date  \
# 0     SAMN08125748  Olleya_Bg11-27         NaN   2017/12/11
# 1              NaN             NaN         NaN   2017/01/26
#
#                Sequencing centers Sequencing depth Sequencing method  \
# 0  University of Alaska Fairbanks             107x               NaN
# 1                             NaN              NaN               NaN
#
#            Sequencing platform Sequencing platform resumed Sequencing status  \
# 0  Illumina MiSeq + ONT MinION   Illumina; Oxford Nanopore               NaN
# 1                          NaN                         NaN               NaN
#
#   Source mat ID  Species taxid Specific host Sporulation   Strain  \
# 0           NaN      2058135.0           NaN         NaN  Bg11-27
# 1           NaN      1936081.0           NaN         NaN      NaN
#
#   Strain name alias Subject ID Submission model Submission package  \
# 0               NaN        NaN          MIGS.ba  MIGS.ba.water.5.0
# 1               NaN        NaN              NaN                NaN
#
#                                            Submitter Subsrc note  \
# 0                     University of Alaska Fairbanks         NaN
# 1  Korea Research Institute of Bioscience & Biote...         NaN
#
#   Supplier name      Taxid Temperature Temperature optimum Temperature range  \
# 0           NaN  2058135.0         NaN                 NaN               NaN
# 1           NaN  1936081.0         NaN                 NaN               NaN
#
#   Title Trophic level Type material Type strain Value Version status  \
# 0   NaN           NaN           NaN         NaN   NaN         latest
# 1   NaN           NaN           NaN         NaN   NaN         latest
#
#   WGS master   pH Terrestrial_coordinates    MAG        Origin
# 0        NaN  NaN                  Marine  False        Marine
# 1        NaN  NaN                     NaN  False  Unclassified

# %%
#bgc_known_metadata.groupby(["Most_similar_known_cluster","Family"]).count()

# %%
df = bgc_known_metadata.groupby(["Family", "Most_similar_known_cluster"]).count()["Genome"].reset_index().rename(columns={"Genome":"Counts per family"})
df = df.pivot(index='Most_similar_known_cluster', columns='Family', values='Counts per family')
df1 = df.fillna(0).reset_index()
df1.head()
# Out:
# Family                         Most_similar_known_cluster  Flavobacteriaceae  \
# 0                                           1-heptadecene                4.0
# 1                 1-nonadecene / (14Z)-1,14-nonadecadiene                1.0
# 2       CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a ...                1.0
# 3                                                  ET-743               29.0
# 4                             K53 capsular polysaccharide                1.0
#
# Family  Weeksellaceae
# 0                 0.0
# 1                 0.0
# 2                 2.0
# 3                 0.0
# 4                 1.0

# %% [markdown]
# ## Known clusters

# %%
df = bgc_known["Most_similar_known_cluster"].value_counts().rename_axis('BGC').reset_index(name='counts')

# %%
merge= pd.merge(df, df1, how="left", left_on="BGC", right_on="Most_similar_known_cluster")
merge.head()
# Out:
#                          BGC  counts Most_similar_known_cluster  \
# 0                 carotenoid    2117                 carotenoid
# 1                 flexirubin    1234                 flexirubin
# 2  putrebactin / avaroferrin     392  putrebactin / avaroferrin
# 3              bisucaberin B     180              bisucaberin B
# 4             bacillomycin D      64             bacillomycin D
#
#    Flavobacteriaceae  Weeksellaceae
# 0             1584.0          533.0
# 1              828.0          406.0
# 2               53.0          339.0
# 3              143.0           37.0
# 4               62.0            2.0

# %%
bgc_known_cluster = bgc_known.groupby("Most_similar_known_cluster").count()
#bgc_known_cluster["Genome"].value_counts()
bgc_known_cluster.head()
# Out:
#                                                     Genome  Region_Type  \
# Most_similar_known_cluster
# 1-heptadecene                                            4            4
# 1-nonadecene / (14Z)-1,14-nonadecadiene                  1            1
# CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a /...       3            3
# ET-743                                                  29           29
# K53 capsular polysaccharide                              2            2
#
#                                                     antiSMASH_classif  \
# Most_similar_known_cluster
# 1-heptadecene                                                       4
# 1-nonadecene / (14Z)-1,14-nonadecadiene                             1
# CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a /...                  3
# ET-743                                                             29
# K53 capsular polysaccharide                                         2
#
#                                                     new_classif  From  To  \
# Most_similar_known_cluster
# 1-heptadecene                                                 4     4   4
# 1-nonadecene / (14Z)-1,14-nonadecadiene                       1     1   1
# CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a /...            3     3   3
# ET-743                                                       29    29  29
# K53 capsular polysaccharide                                   2     2   2
#
#                                                     Size(bp)  \
# Most_similar_known_cluster
# 1-heptadecene                                              4
# 1-nonadecene / (14Z)-1,14-nonadecadiene                    1
# CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a /...         3
# ET-743                                                    29
# K53 capsular polysaccharide                                2
#
#                                                     Most_similar_classif  \
# Most_similar_known_cluster
# 1-heptadecene                                                          4
# 1-nonadecene / (14Z)-1,14-nonadecadiene                                1
# CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a /...                     3
# ET-743                                                                29
# K53 capsular polysaccharide                                            2
#
#                                                     Similarity  Correct_name
# Most_similar_known_cluster
# 1-heptadecene                                                4             4
# 1-nonadecene / (14Z)-1,14-nonadecadiene                      1             1
# CDA1b / CDA2a / CDA2b / CDA3a / CDA3b / CDA4a /...           3             3
# ET-743                                                      29            29
# K53 capsular polysaccharide                                  2             2

# %%
bgc["Known_cluster_count"] = bgc_known.groupby(['Genome']).count()["Most_similar_known_cluster"]
bgc.head()
# Out:
# index            NRPS  NRPS_PKS_hybrid  NRPS_other  Others  PKSI  PKSIII  \
# GCA_002831645.1     0                0           0       1     0       1
# GCA_001971785.1     0                0           0       0     0       0
# GCA_002951395.1     0                0           0       0     0       0
# GCA_903969135.1     1                0           0       1     0       0
# GCA_009664855.1     0                0           0       2     0       1
#
# index            PKS_other  RiPPs  Siderophore  terpene  transAT_PSK  Nr_BGCs  \
# GCA_002831645.1          0      1            0        1            0        4
# GCA_001971785.1          0      1            0        1            0        2
# GCA_002951395.1          0      0            1        1            0        2
# GCA_903969135.1          1      3            1        1            0        8
# GCA_009664855.1          0      2            0        2            0        7
#
# index            Known_cluster_count
# GCA_002831645.1                  1.0
# GCA_001971785.1                  1.0
# GCA_002951395.1                  2.0
# GCA_903969135.1                  2.0
# GCA_009664855.1                  2.0

# %% [markdown]
# ## BGC types with metadata

# %%
merged = pd.merge(bgc, metadata, how="left", left_index=True, right_on="Assembly accession")
merged = merged.set_index("Assembly accession")
merged.head(2)
# Out:
#                     NRPS  NRPS_PKS_hybrid  NRPS_other  Others  PKSI  PKSIII  \
# Assembly accession
# GCA_002831645.1        0                0           0       1     0       1
# GCA_001971785.1        0                0           0       0     0       0
#
#                     PKS_other  RiPPs  Siderophore  terpene  transAT_PSK  \
# Assembly accession
# GCA_002831645.1             0      1            0        1            0
# GCA_001971785.1             0      1            0        1            0
#
#                     Nr_BGCs  Known_cluster_count  \
# Assembly accession
# GCA_002831645.1           4                  1.0
# GCA_001971785.1           2                  1.0
#
#                                                  Bin_Id  \
# Assembly accession
# GCA_002831645.1     GCA_002831645.1_ASM283164v1_genomic
# GCA_001971785.1     GCA_001971785.1_ASM197178v1_genomic
#
#                            Marker lineage  Completeness  Contamination  \
# Assembly accession
# GCA_002831645.1     s__algicola (UID2846)         99.67           0.33
# GCA_001971785.1     s__algicola (UID2846)         98.35           1.25
#
#                     Strain_heterogeneity  Quality_score  \
# Assembly accession
# GCA_002831645.1                      0.0          98.02
# GCA_001971785.1                      0.0          92.10
#
#                                                        classification  \
# Assembly accession
# GCA_002831645.1     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# GCA_001971785.1     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                       Domain         Phyla        Class             Order  \
# Assembly accession
# GCA_002831645.1     Bacteria  Bacteroidota  Bacteroidia  Flavobacteriales
# GCA_001971785.1     Bacteria  Bacteroidota  Bacteroidia  Flavobacteriales
#
#                                Family           Genus  \
# Assembly accession
# GCA_002831645.1     Flavobacteriaceae          Olleya
# GCA_001971785.1     Flavobacteriaceae  Seonamhaeicola
#
#                                        Species  n_scaffolds  n_contigs  \
# Assembly accession
# GCA_002831645.1             Olleya sp002831645          1.0        1.0
# GCA_001971785.1     Seonamhaeicola sp001971785          1.0        1.0
#
#                       scaf_bp  contig_bp  gap_pct  scaf_N50   scaf_L50  \
# Assembly accession
# GCA_002831645.1     4314320.0  4314320.0      0.0       1.0  4314320.0
# GCA_001971785.1     3752836.0  3752836.0      0.0       1.0  3752836.0
#
#                     ctg_N50    ctg_L50  scaf_N90   scaf_L90  ctg_N90  \
# Assembly accession
# GCA_002831645.1         1.0  4314320.0       1.0  4314320.0      1.0
# GCA_001971785.1         1.0  3752836.0       1.0  3752836.0      1.0
#
#                       ctg_L90   scaf_max    ctg_max  scaf_n_gt50K  \
# Assembly accession
# GCA_002831645.1     4314320.0  4314320.0  4314320.0           1.0
# GCA_001971785.1     3752836.0  3752836.0  3752836.0           1.0
#
#                     scaf_pct_gt50K   gc_avg  gc_std Classification_quality  \
# Assembly accession
# GCA_002831645.1              100.0  0.32759     0.0                   High
# GCA_001971785.1              100.0  0.32262     0.0                   High
#
#                       orfs    pfam      ko     cog  cazymes  Orfs_anno_pfam%  \
# Assembly accession
# GCA_002831645.1     3835.0  2862.0  1368.0  2230.0     90.0        74.628422
# GCA_001971785.1     3259.0  2629.0  1367.0  2134.0    140.0        80.668917
#
#                     Orfs_anno_ko%  Orfs_anno_cog%  Orfs_anno_cazymes%  \
# Assembly accession
# GCA_002831645.1         35.671447       58.148631            2.346806
# GCA_001971785.1         41.945382       65.480209            4.295796
#
#                        ASM name Alias Altitude Anonymized name  \
# Assembly accession
# GCA_002831645.1     ASM283164v1   NaN      NaN             NaN
# GCA_001971785.1     ASM197178v1   NaN      NaN             NaN
#
#                    Arrayexpress species Arrayexpress strain or line  \
# Assembly accession
# GCA_002831645.1                     NaN                         NaN
# GCA_001971785.1                     NaN                         NaN
#
#                      Assembly level     Assembly method  \
# Assembly accession
# GCA_002831645.1     Complete Genome  Unicycler v. 0.3.1
# GCA_001971785.1     Complete Genome                 NaN
#
#                    Assembly method resumed Biomaterial provider  \
# Assembly accession
# GCA_002831645.1         Unicycler v. 0.3.1                  NaN
# GCA_001971785.1                        NaN                  NaN
#
#                    Bioproject accession Biosample accession Biosample model  \
# Assembly accession
# GCA_002831645.1             PRJNA420923        SAMN08125748             NaN
# GCA_001971785.1             PRJNA362242        SAMN06236790             NaN
#
#                                                       Biosample title  \
# Assembly accession
# GCA_002831645.1     MIGS Cultured Bacterial/Archaeal sample from O...
# GCA_001971785.1                                                   NaN
#
#                    Biotic relationship Body sample site Cell shape  \
# Assembly accession
# GCA_002831645.1                    NaN              NaN        NaN
# GCA_001971785.1                    NaN              NaN        NaN
#
#                    Collected by Collection date            Comment paragraph  \
# Assembly accession
# GCA_002831645.1             NaN            2014  Keywords: GSC:MIxS;MIGS:5.0
# GCA_001971785.1             NaN             NaN                          NaN
#
#                          Completion date       Contact email Contact lab  \
# Assembly accession
# GCA_002831645.1     2017-12-11T00:00:00Z  cryomics@gmail.com         NaN
# GCA_001971785.1                      NaN                 NaN         NaN
#
#                     Contigs Country Culture collection Depth Derived from  \
# Assembly accession
# GCA_002831645.1         1.0     NaN                NaN     0          NaN
# GCA_001971785.1         NaN     NaN                NaN   NaN          NaN
#
#                    Description Disease ENA checklist ENA-first-public  \
# Assembly accession
# GCA_002831645.1            NaN     NaN           NaN              NaN
# GCA_001971785.1            NaN     NaN           NaN              NaN
#
#                    ENA-last-update Elevation     Env biome Env broad scale  \
# Assembly accession
# GCA_002831645.1                NaN       NaN  marine biome             NaN
# GCA_001971785.1                NaN       NaN           NaN             NaN
#
#                      Env feature Env local scale Env material Env medium  \
# Assembly accession
# GCA_002831645.1     sea ice floe             NaN      sea ice        NaN
# GCA_001971785.1              NaN             NaN          NaN        NaN
#
#                    Environment Environmental sample Estimated size  \
# Assembly accession
# GCA_002831645.1            NaN                  NaN            NaN
# GCA_001971785.1            NaN                  NaN            NaN
#
#                    Excluded from refseq FDA cvm ID  \
# Assembly accession
# GCA_002831645.1                     NaN        NaN
# GCA_001971785.1                     NaN        NaN
#
#                    Finishing strategy (depth of coverage) First name  \
# Assembly accession
# GCA_002831645.1                                       NaN       Eric
# GCA_001971785.1                                       NaN        NaN
#
#                                                              Ftp path  \
# Assembly accession
# GCA_002831645.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002...
# GCA_001971785.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001...
#
#                    GOLD stamp ID  Gbrs paired ASM Genbank accessions  \
# Assembly accession
# GCA_002831645.1              NaN  GCF_002831645.1           CP025117
# GCA_001971785.1              NaN  GCF_001971785.1                NaN
#
#                    Gene calling method         Genome name  \
# Assembly accession
# GCA_002831645.1                    NaN  Olleya sp. Bg11-27
# GCA_001971785.1                    NaN                 NaN
#
#                    Genome quality flags Genome rep Genome status Genotype  \
# Assembly accession
# GCA_002831645.1                     NaN       Full      Complete      NaN
# GCA_001971785.1                     NaN       Full           NaN      NaN
#
#                                Geographic location Geographic location (city)  \
# Assembly accession
# GCA_002831645.1     USA: near Point Barrow, Alaska  near Point Barrow, Alaska
# GCA_001971785.1                                NaN                        NaN
#
#                    Geographic location (country or region) Gram stain Habitat  \
# Assembly accession
# GCA_002831645.1                                        USA        NaN     NaN
# GCA_001971785.1                                        NaN        NaN     NaN
#
#                    Host Host age Host disease Host disease outcome  \
# Assembly accession
# GCA_002831645.1     NaN      NaN          NaN                  NaN
# GCA_001971785.1     NaN      NaN          NaN                  NaN
#
#                    Host gender Host health Host name Host resumed  \
# Assembly accession
# GCA_002831645.1            NaN         NaN       NaN          NaN
# GCA_001971785.1            NaN         NaN       NaN          NaN
#
#                    Host scientific name Host sex  Host taxid  \
# Assembly accession
# GCA_002831645.1                     NaN      NaN         NaN
# GCA_001971785.1                     NaN      NaN         NaN
#
#                    Host tissue sampled INSDC center alias INSDC center name  \
# Assembly accession
# GCA_002831645.1                    NaN                NaN               NaN
# GCA_001971785.1                    NaN                NaN               NaN
#
#                    INSDC first public INSDC last update INSDC status  \
# Assembly accession
# GCA_002831645.1                   NaN               NaN          NaN
# GCA_001971785.1                   NaN               NaN          NaN
#
#                    Identification method Identified by Infraspecific name  \
# Assembly accession
# GCA_002831645.1                      NaN           NaN     strain=Bg11-27
# GCA_001971785.1                      NaN           NaN        strain=S2-3
#
#                    Investigation type    Isol growth condt Isolate  \
# Assembly accession
# GCA_002831645.1                   NaN  Bg11 medium, 4deg C     NaN
# GCA_001971785.1                   NaN                  NaN     NaN
#
#                    Isolation comments Isolation country Isolation site  \
# Assembly accession
# GCA_002831645.1                   NaN     United States            NaN
# GCA_001971785.1                   NaN               NaN            NaN
#
#                    Isolation source Last name Latitude Locus tag prefix  \
# Assembly accession
# GCA_002831645.1             sea ice   Collins     71.3              NaN
# GCA_001971785.1                 NaN       NaN      NaN              NaN
#
#                    Longitude MLST Mapping method and version Material  \
# Assembly accession
# GCA_002831645.1         -157  NaN                        NaN      NaN
# GCA_001971785.1          NaN  NaN                        NaN      NaN
#
#                    Metagenome source Misc param Misc param: hmp supersite  \
# Assembly accession
# GCA_002831645.1                  NaN        NaN                       NaN
# GCA_001971785.1                  NaN        NaN                       NaN
#
#                    Motility                            Name  Ncbi taxon ID  \
# Assembly accession
# GCA_002831645.1         NaN  University of Alaska Fairbanks      2058135.0
# GCA_001971785.1         NaN                             NaN            NaN
#
#                    Note            Organism            Organism name  \
# Assembly accession
# GCA_002831645.1     NaN  Olleya sp. Bg11-27       Olleya sp. Bg11-27
# GCA_001971785.1     NaN                 NaN  Seonamhaeicola sp. S2-3
#
#                    Other clinical     Other environmental Oxygen requirement  \
# Assembly accession
# GCA_002831645.1               NaN  env_biome:marine biome                NaN
# GCA_001971785.1               NaN                     NaN                NaN
#
#                    Paired ASM comp Phenotypes  Plasmids Project name  \
# Assembly accession
# GCA_002831645.1          identical        NaN       NaN          NaN
# GCA_001971785.1          identical        NaN       NaN          NaN
#
#                    Project type Publication         Publication date  \
# Assembly accession
# GCA_002831645.1             NaN         NaN  2017-12-04T00:00:00.000
# GCA_001971785.1             NaN         NaN                      NaN
#
#                    Ref biomaterial Refseq accessions Refseq category  \
# Assembly accession
# GCA_002831645.1                NaN               NaN             NaN
# GCA_001971785.1                NaN               NaN             NaN
#
#                     Refseq cds Rel to oxygen Relation to type material  \
# Assembly accession
# GCA_002831645.1         3803.0           NaN                       NaN
# GCA_001971785.1            NaN           NaN                       NaN
#
#                    Release type SRA accession Salinity Sample accession  \
# Assembly accession
# GCA_002831645.1           Major           NaN      NaN     SAMN08125748
# GCA_001971785.1           Major           NaN      NaN              NaN
#
#                        Sample name Sample type Seq rel date  \
# Assembly accession
# GCA_002831645.1     Olleya_Bg11-27         NaN   2017/12/11
# GCA_001971785.1                NaN         NaN   2017/01/26
#
#                                 Sequencing centers Sequencing depth  \
# Assembly accession
# GCA_002831645.1     University of Alaska Fairbanks             107x
# GCA_001971785.1                                NaN              NaN
#
#                    Sequencing method          Sequencing platform  \
# Assembly accession
# GCA_002831645.1                  NaN  Illumina MiSeq + ONT MinION
# GCA_001971785.1                  NaN                          NaN
#
#                    Sequencing platform resumed Sequencing status  \
# Assembly accession
# GCA_002831645.1      Illumina; Oxford Nanopore               NaN
# GCA_001971785.1                            NaN               NaN
#
#                    Source mat ID  Species taxid Specific host Sporulation  \
# Assembly accession
# GCA_002831645.1              NaN      2058135.0           NaN         NaN
# GCA_001971785.1              NaN      1936081.0           NaN         NaN
#
#                      Strain Strain name alias Subject ID Submission model  \
# Assembly accession
# GCA_002831645.1     Bg11-27               NaN        NaN          MIGS.ba
# GCA_001971785.1         NaN               NaN        NaN              NaN
#
#                    Submission package  \
# Assembly accession
# GCA_002831645.1     MIGS.ba.water.5.0
# GCA_001971785.1                   NaN
#
#                                                             Submitter  \
# Assembly accession
# GCA_002831645.1                        University of Alaska Fairbanks
# GCA_001971785.1     Korea Research Institute of Bioscience & Biote...
#
#                    Subsrc note Supplier name      Taxid Temperature  \
# Assembly accession
# GCA_002831645.1            NaN           NaN  2058135.0         NaN
# GCA_001971785.1            NaN           NaN  1936081.0         NaN
#
#                    Temperature optimum Temperature range Title Trophic level  \
# Assembly accession
# GCA_002831645.1                    NaN               NaN   NaN           NaN
# GCA_001971785.1                    NaN               NaN   NaN           NaN
#
#                    Type material Type strain Value Version status WGS master  \
# Assembly accession
# GCA_002831645.1              NaN         NaN   NaN         latest        NaN
# GCA_001971785.1              NaN         NaN   NaN         latest        NaN
#
#                      pH Terrestrial_coordinates    MAG        Origin
# Assembly accession
# GCA_002831645.1     NaN                  Marine  False        Marine
# GCA_001971785.1     NaN                     NaN  False  Unclassified

# %%
merged.Family.value_counts()
# Out:
# Flavobacteriaceae    1860
# Weeksellaceae         681
# Name: Family, dtype: int64

# %% [markdown]
# ### Conversions

# %%
numerical = merged.select_dtypes(include="int")
numerical.head(2)
# Out:
#                     NRPS  NRPS_PKS_hybrid  NRPS_other  Others  PKSI  PKSIII  \
# Assembly accession
# GCA_002831645.1        0                0           0       1     0       1
# GCA_001971785.1        0                0           0       0     0       0
#
#                     PKS_other  RiPPs  Siderophore  terpene  transAT_PSK  \
# Assembly accession
# GCA_002831645.1             0      1            0        1            0
# GCA_001971785.1             0      1            0        1            0
#
#                     Nr_BGCs
# Assembly accession
# GCA_002831645.1           4
# GCA_001971785.1           2

# %%
categorical = merged.select_dtypes(include="object")
categorical.head(2)
# Out:
#                                                  Bin_Id  \
# Assembly accession
# GCA_002831645.1     GCA_002831645.1_ASM283164v1_genomic
# GCA_001971785.1     GCA_001971785.1_ASM197178v1_genomic
#
#                            Marker lineage  \
# Assembly accession
# GCA_002831645.1     s__algicola (UID2846)
# GCA_001971785.1     s__algicola (UID2846)
#
#                                                        classification  \
# Assembly accession
# GCA_002831645.1     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
# GCA_001971785.1     d__Bacteria;p__Bacteroidota;c__Bacteroidia;o__...
#
#                       Domain         Phyla        Class             Order  \
# Assembly accession
# GCA_002831645.1     Bacteria  Bacteroidota  Bacteroidia  Flavobacteriales
# GCA_001971785.1     Bacteria  Bacteroidota  Bacteroidia  Flavobacteriales
#
#                                Family           Genus  \
# Assembly accession
# GCA_002831645.1     Flavobacteriaceae          Olleya
# GCA_001971785.1     Flavobacteriaceae  Seonamhaeicola
#
#                                        Species Classification_quality  \
# Assembly accession
# GCA_002831645.1             Olleya sp002831645                   High
# GCA_001971785.1     Seonamhaeicola sp001971785                   High
#
#                        ASM name Alias Altitude Anonymized name  \
# Assembly accession
# GCA_002831645.1     ASM283164v1   NaN      NaN             NaN
# GCA_001971785.1     ASM197178v1   NaN      NaN             NaN
#
#                    Arrayexpress species Arrayexpress strain or line  \
# Assembly accession
# GCA_002831645.1                     NaN                         NaN
# GCA_001971785.1                     NaN                         NaN
#
#                      Assembly level     Assembly method  \
# Assembly accession
# GCA_002831645.1     Complete Genome  Unicycler v. 0.3.1
# GCA_001971785.1     Complete Genome                 NaN
#
#                    Assembly method resumed Biomaterial provider  \
# Assembly accession
# GCA_002831645.1         Unicycler v. 0.3.1                  NaN
# GCA_001971785.1                        NaN                  NaN
#
#                    Bioproject accession Biosample accession Biosample model  \
# Assembly accession
# GCA_002831645.1             PRJNA420923        SAMN08125748             NaN
# GCA_001971785.1             PRJNA362242        SAMN06236790             NaN
#
#                                                       Biosample title  \
# Assembly accession
# GCA_002831645.1     MIGS Cultured Bacterial/Archaeal sample from O...
# GCA_001971785.1                                                   NaN
#
#                    Biotic relationship Body sample site Cell shape  \
# Assembly accession
# GCA_002831645.1                    NaN              NaN        NaN
# GCA_001971785.1                    NaN              NaN        NaN
#
#                    Collected by Collection date            Comment paragraph  \
# Assembly accession
# GCA_002831645.1             NaN            2014  Keywords: GSC:MIxS;MIGS:5.0
# GCA_001971785.1             NaN             NaN                          NaN
#
#                          Completion date       Contact email Contact lab  \
# Assembly accession
# GCA_002831645.1     2017-12-11T00:00:00Z  cryomics@gmail.com         NaN
# GCA_001971785.1                      NaN                 NaN         NaN
#
#                    Country Culture collection Depth Derived from Description  \
# Assembly accession
# GCA_002831645.1        NaN                NaN     0          NaN         NaN
# GCA_001971785.1        NaN                NaN   NaN          NaN         NaN
#
#                    Disease ENA checklist ENA-first-public ENA-last-update  \
# Assembly accession
# GCA_002831645.1        NaN           NaN              NaN             NaN
# GCA_001971785.1        NaN           NaN              NaN             NaN
#
#                    Elevation     Env biome Env broad scale   Env feature  \
# Assembly accession
# GCA_002831645.1          NaN  marine biome             NaN  sea ice floe
# GCA_001971785.1          NaN           NaN             NaN           NaN
#
#                    Env local scale Env material Env medium Environment  \
# Assembly accession
# GCA_002831645.1                NaN      sea ice        NaN         NaN
# GCA_001971785.1                NaN          NaN        NaN         NaN
#
#                    Environmental sample Estimated size Excluded from refseq  \
# Assembly accession
# GCA_002831645.1                     NaN            NaN                  NaN
# GCA_001971785.1                     NaN            NaN                  NaN
#
#                    FDA cvm ID Finishing strategy (depth of coverage)  \
# Assembly accession
# GCA_002831645.1           NaN                                    NaN
# GCA_001971785.1           NaN                                    NaN
#
#                    First name  \
# Assembly accession
# GCA_002831645.1          Eric
# GCA_001971785.1           NaN
#
#                                                              Ftp path  \
# Assembly accession
# GCA_002831645.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/002...
# GCA_001971785.1     ftp://ftp.ncbi.nlm.nih.gov/genomes/all/GCA/001...
#
#                    GOLD stamp ID  Gbrs paired ASM Genbank accessions  \
# Assembly accession
# GCA_002831645.1              NaN  GCF_002831645.1           CP025117
# GCA_001971785.1              NaN  GCF_001971785.1                NaN
#
#                    Gene calling method         Genome name  \
# Assembly accession
# GCA_002831645.1                    NaN  Olleya sp. Bg11-27
# GCA_001971785.1                    NaN                 NaN
#
#                    Genome quality flags Genome rep Genome status Genotype  \
# Assembly accession
# GCA_002831645.1                     NaN       Full      Complete      NaN
# GCA_001971785.1                     NaN       Full           NaN      NaN
#
#                                Geographic location Geographic location (city)  \
# Assembly accession
# GCA_002831645.1     USA: near Point Barrow, Alaska  near Point Barrow, Alaska
# GCA_001971785.1                                NaN                        NaN
#
#                    Geographic location (country or region) Gram stain Habitat  \
# Assembly accession
# GCA_002831645.1                                        USA        NaN     NaN
# GCA_001971785.1                                        NaN        NaN     NaN
#
#                    Host Host age Host disease Host disease outcome  \
# Assembly accession
# GCA_002831645.1     NaN      NaN          NaN                  NaN
# GCA_001971785.1     NaN      NaN          NaN                  NaN
#
#                    Host gender Host health Host name Host resumed  \
# Assembly accession
# GCA_002831645.1            NaN         NaN       NaN          NaN
# GCA_001971785.1            NaN         NaN       NaN          NaN
#
#                    Host scientific name Host sex Host tissue sampled  \
# Assembly accession
# GCA_002831645.1                     NaN      NaN                 NaN
# GCA_001971785.1                     NaN      NaN                 NaN
#
#                    INSDC center alias INSDC center name INSDC first public  \
# Assembly accession
# GCA_002831645.1                   NaN               NaN                NaN
# GCA_001971785.1                   NaN               NaN                NaN
#
#                    INSDC last update INSDC status Identification method  \
# Assembly accession
# GCA_002831645.1                  NaN          NaN                   NaN
# GCA_001971785.1                  NaN          NaN                   NaN
#
#                    Identified by Infraspecific name Investigation type  \
# Assembly accession
# GCA_002831645.1              NaN     strain=Bg11-27                NaN
# GCA_001971785.1              NaN        strain=S2-3                NaN
#
#                       Isol growth condt Isolate Isolation comments  \
# Assembly accession
# GCA_002831645.1     Bg11 medium, 4deg C     NaN                NaN
# GCA_001971785.1                     NaN     NaN                NaN
#
#                    Isolation country Isolation site Isolation source  \
# Assembly accession
# GCA_002831645.1        United States            NaN          sea ice
# GCA_001971785.1                  NaN            NaN              NaN
#
#                    Last name Latitude Locus tag prefix Longitude MLST  \
# Assembly accession
# GCA_002831645.1      Collins     71.3              NaN      -157  NaN
# GCA_001971785.1          NaN      NaN              NaN       NaN  NaN
#
#                    Mapping method and version Material Metagenome source  \
# Assembly accession
# GCA_002831645.1                           NaN      NaN               NaN
# GCA_001971785.1                           NaN      NaN               NaN
#
#                    Misc param Misc param: hmp supersite Motility  \
# Assembly accession
# GCA_002831645.1           NaN                       NaN      NaN
# GCA_001971785.1           NaN                       NaN      NaN
#
#                                               Name Note            Organism  \
# Assembly accession
# GCA_002831645.1     University of Alaska Fairbanks  NaN  Olleya sp. Bg11-27
# GCA_001971785.1                                NaN  NaN                 NaN
#
#                               Organism name Other clinical  \
# Assembly accession
# GCA_002831645.1          Olleya sp. Bg11-27            NaN
# GCA_001971785.1     Seonamhaeicola sp. S2-3            NaN
#
#                        Other environmental Oxygen requirement Paired ASM comp  \
# Assembly accession
# GCA_002831645.1     env_biome:marine biome                NaN       identical
# GCA_001971785.1                        NaN                NaN       identical
#
#                    Phenotypes Project name Project type Publication  \
# Assembly accession
# GCA_002831645.1           NaN          NaN          NaN         NaN
# GCA_001971785.1           NaN          NaN          NaN         NaN
#
#                            Publication date Ref biomaterial Refseq accessions  \
# Assembly accession
# GCA_002831645.1     2017-12-04T00:00:00.000             NaN               NaN
# GCA_001971785.1                         NaN             NaN               NaN
#
#                    Refseq category Rel to oxygen Relation to type material  \
# Assembly accession
# GCA_002831645.1                NaN           NaN                       NaN
# GCA_001971785.1                NaN           NaN                       NaN
#
#                    Release type SRA accession Salinity Sample accession  \
# Assembly accession
# GCA_002831645.1           Major           NaN      NaN     SAMN08125748
# GCA_001971785.1           Major           NaN      NaN              NaN
#
#                        Sample name Sample type Seq rel date  \
# Assembly accession
# GCA_002831645.1     Olleya_Bg11-27         NaN   2017/12/11
# GCA_001971785.1                NaN         NaN   2017/01/26
#
#                                 Sequencing centers Sequencing depth  \
# Assembly accession
# GCA_002831645.1     University of Alaska Fairbanks             107x
# GCA_001971785.1                                NaN              NaN
#
#                    Sequencing method          Sequencing platform  \
# Assembly accession
# GCA_002831645.1                  NaN  Illumina MiSeq + ONT MinION
# GCA_001971785.1                  NaN                          NaN
#
#                    Sequencing platform resumed Sequencing status  \
# Assembly accession
# GCA_002831645.1      Illumina; Oxford Nanopore               NaN
# GCA_001971785.1                            NaN               NaN
#
#                    Source mat ID Specific host Sporulation   Strain  \
# Assembly accession
# GCA_002831645.1              NaN           NaN         NaN  Bg11-27
# GCA_001971785.1              NaN           NaN         NaN      NaN
#
#                    Strain name alias Subject ID Submission model  \
# Assembly accession
# GCA_002831645.1                  NaN        NaN          MIGS.ba
# GCA_001971785.1                  NaN        NaN              NaN
#
#                    Submission package  \
# Assembly accession
# GCA_002831645.1     MIGS.ba.water.5.0
# GCA_001971785.1                   NaN
#
#                                                             Submitter  \
# Assembly accession
# GCA_002831645.1                        University of Alaska Fairbanks
# GCA_001971785.1     Korea Research Institute of Bioscience & Biote...
#
#                    Subsrc note Supplier name      Taxid Temperature  \
# Assembly accession
# GCA_002831645.1            NaN           NaN  2058135.0         NaN
# GCA_001971785.1            NaN           NaN  1936081.0         NaN
#
#                    Temperature optimum Temperature range Title Trophic level  \
# Assembly accession
# GCA_002831645.1                    NaN               NaN   NaN           NaN
# GCA_001971785.1                    NaN               NaN   NaN           NaN
#
#                    Type material Type strain Value Version status WGS master  \
# Assembly accession
# GCA_002831645.1              NaN         NaN   NaN         latest        NaN
# GCA_001971785.1              NaN         NaN   NaN         latest        NaN
#
#                      pH Terrestrial_coordinates    MAG        Origin
# Assembly accession
# GCA_002831645.1     NaN                  Marine  False        Marine
# GCA_001971785.1     NaN                     NaN  False  Unclassified

# %%
bgc_types = merged[["NRPS", "NRPS_other", "PKSI", "PKSIII",  "PKS_other", "RiPPs", "Others", "Siderophore", "terpene","transAT_PSK", 
                    "Genus", "Family", "Nr_BGCs", "Origin", "Known_cluster_count"]]

# %%
bgc_flavo = bgc_types[bgc_types["Family"] == "Flavobacteriaceae"]

# %%
bgc_types.sort_values(by="Nr_BGCs", ascending=False).head(3)
# Out:
#                     NRPS  NRPS_other  PKSI  PKSIII  PKS_other  RiPPs  Others  \
# Assembly accession
# GCA_902728265.1       24           2     0       0          0      3       1
# GCA_008370685.1        5           0     0       1          1      4       3
# GCA_902804485.1       11           0     1       0          1      1       3
#
#                     Siderophore  terpene  transAT_PSK             Genus  \
# Assembly accession
# GCA_902728265.1               0        0            0  Chryseobacterium
# GCA_008370685.1               1        3            2        Aquimarina
# GCA_902804485.1               1        2            0    Flavobacterium
#
#                                Family  Nr_BGCs        Origin  \
# Assembly accession
# GCA_902728265.1         Weeksellaceae       31    Non_marine
# GCA_008370685.1     Flavobacteriaceae       23  Unclassified
# GCA_902804485.1     Flavobacteriaceae       22  Unclassified
#
#                     Known_cluster_count
# Assembly accession
# GCA_902728265.1                     5.0
# GCA_008370685.1                     5.0
# GCA_902804485.1                     5.0

# %%
final = bgc_types.groupby(['Genus']).filter(lambda x:x['Genus'].count()>5).groupby(['Genus', "Family"]).describe().round(1)
finalx = final.reset_index()
finalx= finalx.T.reset_index()
finalx["Stats"]= finalx[['level_0', 'level_1']].agg('_'.join, axis=1)
finalx = finalx.set_index("Stats")
finalx = finalx.drop(columns=['level_0', 'level_1'])
finalx= finalx.T
finalx = finalx.rename(columns={"Genus_":"Genus", "Family_":"Family"})
#finalx = finalx.sort_values(by="orfs_count", ascending=False)
finalx = finalx.sort_values(by="Family", ascending=False)
finalx.head()
# Out:
# Stats             Genus         Family NRPS_count NRPS_mean NRPS_std NRPS_min  \
# 10     Chryseobacterium  Weeksellaceae        294       1.3      1.9        0
# 3             Apibacter  Weeksellaceae         21         0        0        0
# 25            Kaistella  Weeksellaceae         48         0        0        0
# 17      Epilithonimonas  Weeksellaceae         31         0        0        0
# 16         Empedobacter  Weeksellaceae         41         0      0.2        0
#
# Stats NRPS_25% NRPS_50% NRPS_75% NRPS_max NRPS_other_count NRPS_other_mean  \
# 10           0        1        2       24              294             0.2
# 3            0        0        0        0               21               0
# 25           0        0        0        0               48               0
# 17           0        0        0        0               31               0
# 16           0        0        0        1               41               0
#
# Stats NRPS_other_std NRPS_other_min NRPS_other_25% NRPS_other_50%  \
# 10               0.5              0              0              0
# 3                  0              0              0              0
# 25                 0              0              0              0
# 17                 0              0              0              0
# 16                 0              0              0              0
#
# Stats NRPS_other_75% NRPS_other_max PKSI_count PKSI_mean PKSI_std PKSI_min  \
# 10                 0              3        294         0      0.1        0
# 3                  0              0         21         0        0        0
# 25                 0              0         48         0        0        0
# 17                 0              0         31         0        0        0
# 16                 0              0         41         0        0        0
#
# Stats PKSI_25% PKSI_50% PKSI_75% PKSI_max PKSIII_count PKSIII_mean PKSIII_std  \
# 10           0        0        0        2          294           0          0
# 3            0        0        0        0           21           0          0
# 25           0        0        0        0           48         0.6        0.5
# 17           0        0        0        0           31           0          0
# 16           0        0        0        0           41           0          0
#
# Stats PKSIII_min PKSIII_25% PKSIII_50% PKSIII_75% PKSIII_max PKS_other_count  \
# 10             0          0          0          0          0             294
# 3              0          0          0          0          0              21
# 25             0          0          1          1          1              48
# 17             0          0          0          0          0              31
# 16             0          0          0          0          0              41
#
# Stats PKS_other_mean PKS_other_std PKS_other_min PKS_other_25% PKS_other_50%  \
# 10               0.7           0.5             0             0             1
# 3                  1             0             1             1             1
# 25                 0             0             0             0             0
# 17                 0             0             0             0             0
# 16                 0             0             0             0             0
#
# Stats PKS_other_75% PKS_other_max RiPPs_count RiPPs_mean RiPPs_std RiPPs_min  \
# 10                1             2         294        2.4       1.3         0
# 3                 1             1          21          0         0         0
# 25                0             0          48          0       0.1         0
# 17                0             0          31        0.5       0.7         0
# 16                0             0          41        0.2       0.4         0
#
# Stats RiPPs_25% RiPPs_50% RiPPs_75% RiPPs_max Others_count Others_mean  \
# 10            2         2         3         6          294         1.2
# 3             0         0         0         0           21         0.1
# 25            0         0         0         1           48           0
# 17            0         0         1         3           31         0.5
# 16            0         0         0         1           41         1.2
#
# Stats Others_std Others_min Others_25% Others_50% Others_75% Others_max  \
# 10           0.5          1          1          1          1          5
# 3            0.3          0          0          0          0          1
# 25           0.2          0          0          0          0          1
# 17           0.7          0          0          0          1          2
# 16           0.7          0          1          1          1          3
#
# Stats Siderophore_count Siderophore_mean Siderophore_std Siderophore_min  \
# 10                  294              0.7             0.5               0
# 3                    21                0               0               0
# 25                   48                0               0               0
# 17                   31                0               0               0
# 16                   41                0               0               0
#
# Stats Siderophore_25% Siderophore_50% Siderophore_75% Siderophore_max  \
# 10                  0               1               1               2
# 3                   0               0               0               0
# 25                  0               0               0               0
# 17                  0               0               0               0
# 16                  0               0               0               0
#
# Stats terpene_count terpene_mean terpene_std terpene_min terpene_25%  \
# 10              294          1.1         1.1           0           0
# 3                21            0           0           0           0
# 25               48          1.2         0.5           0           1
# 17               31            1         0.3           0           1
# 16               41          0.8         0.5           0           1
#
# Stats terpene_50% terpene_75% terpene_max transAT_PSK_count transAT_PSK_mean  \
# 10              1           1           6               294                0
# 3               0           0           0                21                0
# 25              1           1           2                48                0
# 17              1           1           2                31                0
# 16              1           1           2                41                0
#
# Stats transAT_PSK_std transAT_PSK_min transAT_PSK_25% transAT_PSK_50%  \
# 10                  0               0               0               0
# 3                   0               0               0               0
# 25                  0               0               0               0
# 17                  0               0               0               0
# 16                  0               0               0               0
#
# Stats transAT_PSK_75% transAT_PSK_max Nr_BGCs_count Nr_BGCs_mean Nr_BGCs_std  \
# 10                  0               0           294          7.7         3.4
# 3                   0               0            21          1.1         0.3
# 25                  0               0            48          1.9         0.8
# 17                  0               0            31            2         0.9
# 16                  0               0            41          2.3         0.8
#
# Stats Nr_BGCs_min Nr_BGCs_25% Nr_BGCs_50% Nr_BGCs_75% Nr_BGCs_max  \
# 10              1           6           8           9          31
# 3               1           1           1           1           2
# 25              1           1           2         2.2           3
# 17              1           1           2         2.5           5
# 16              1           2           2           3           5
#
# Stats Known_cluster_count_count Known_cluster_count_mean  \
# 10                          294                      2.8
# 3                             2                        1
# 25                           45                        1
# 17                           29                      1.6
# 16                           39                        2
#
# Stats Known_cluster_count_std Known_cluster_count_min Known_cluster_count_25%  \
# 10                        0.8                       1                       2
# 3                           0                       1                       1
# 25                          0                       1                       1
# 17                        0.6                       1                       1
# 16                        0.7                       1                       2
#
# Stats Known_cluster_count_50% Known_cluster_count_75% Known_cluster_count_max
# 10                          3                       3                       7
# 3                           1                       1                       1
# 25                          1                       1                       1
# 17                          1                       2                       3
# 16                          2                       2                       4

# %%
finalx.head()
# Out:
# Stats             Genus         Family NRPS_count NRPS_mean NRPS_std NRPS_min  \
# 10     Chryseobacterium  Weeksellaceae        294       1.3      1.9        0
# 3             Apibacter  Weeksellaceae         21         0        0        0
# 25            Kaistella  Weeksellaceae         48         0        0        0
# 17      Epilithonimonas  Weeksellaceae         31         0        0        0
# 16         Empedobacter  Weeksellaceae         41         0      0.2        0
#
# Stats NRPS_25% NRPS_50% NRPS_75% NRPS_max NRPS_other_count NRPS_other_mean  \
# 10           0        1        2       24              294             0.2
# 3            0        0        0        0               21               0
# 25           0        0        0        0               48               0
# 17           0        0        0        0               31               0
# 16           0        0        0        1               41               0
#
# Stats NRPS_other_std NRPS_other_min NRPS_other_25% NRPS_other_50%  \
# 10               0.5              0              0              0
# 3                  0              0              0              0
# 25                 0              0              0              0
# 17                 0              0              0              0
# 16                 0              0              0              0
#
# Stats NRPS_other_75% NRPS_other_max PKSI_count PKSI_mean PKSI_std PKSI_min  \
# 10                 0              3        294         0      0.1        0
# 3                  0              0         21         0        0        0
# 25                 0              0         48         0        0        0
# 17                 0              0         31         0        0        0
# 16                 0              0         41         0        0        0
#
# Stats PKSI_25% PKSI_50% PKSI_75% PKSI_max PKSIII_count PKSIII_mean PKSIII_std  \
# 10           0        0        0        2          294           0          0
# 3            0        0        0        0           21           0          0
# 25           0        0        0        0           48         0.6        0.5
# 17           0        0        0        0           31           0          0
# 16           0        0        0        0           41           0          0
#
# Stats PKSIII_min PKSIII_25% PKSIII_50% PKSIII_75% PKSIII_max PKS_other_count  \
# 10             0          0          0          0          0             294
# 3              0          0          0          0          0              21
# 25             0          0          1          1          1              48
# 17             0          0          0          0          0              31
# 16             0          0          0          0          0              41
#
# Stats PKS_other_mean PKS_other_std PKS_other_min PKS_other_25% PKS_other_50%  \
# 10               0.7           0.5             0             0             1
# 3                  1             0             1             1             1
# 25                 0             0             0             0             0
# 17                 0             0             0             0             0
# 16                 0             0             0             0             0
#
# Stats PKS_other_75% PKS_other_max RiPPs_count RiPPs_mean RiPPs_std RiPPs_min  \
# 10                1             2         294        2.4       1.3         0
# 3                 1             1          21          0         0         0
# 25                0             0          48          0       0.1         0
# 17                0             0          31        0.5       0.7         0
# 16                0             0          41        0.2       0.4         0
#
# Stats RiPPs_25% RiPPs_50% RiPPs_75% RiPPs_max Others_count Others_mean  \
# 10            2         2         3         6          294         1.2
# 3             0         0         0         0           21         0.1
# 25            0         0         0         1           48           0
# 17            0         0         1         3           31         0.5
# 16            0         0         0         1           41         1.2
#
# Stats Others_std Others_min Others_25% Others_50% Others_75% Others_max  \
# 10           0.5          1          1          1          1          5
# 3            0.3          0          0          0          0          1
# 25           0.2          0          0          0          0          1
# 17           0.7          0          0          0          1          2
# 16           0.7          0          1          1          1          3
#
# Stats Siderophore_count Siderophore_mean Siderophore_std Siderophore_min  \
# 10                  294              0.7             0.5               0
# 3                    21                0               0               0
# 25                   48                0               0               0
# 17                   31                0               0               0
# 16                   41                0               0               0
#
# Stats Siderophore_25% Siderophore_50% Siderophore_75% Siderophore_max  \
# 10                  0               1               1               2
# 3                   0               0               0               0
# 25                  0               0               0               0
# 17                  0               0               0               0
# 16                  0               0               0               0
#
# Stats terpene_count terpene_mean terpene_std terpene_min terpene_25%  \
# 10              294          1.1         1.1           0           0
# 3                21            0           0           0           0
# 25               48          1.2         0.5           0           1
# 17               31            1         0.3           0           1
# 16               41          0.8         0.5           0           1
#
# Stats terpene_50% terpene_75% terpene_max transAT_PSK_count transAT_PSK_mean  \
# 10              1           1           6               294                0
# 3               0           0           0                21                0
# 25              1           1           2                48                0
# 17              1           1           2                31                0
# 16              1           1           2                41                0
#
# Stats transAT_PSK_std transAT_PSK_min transAT_PSK_25% transAT_PSK_50%  \
# 10                  0               0               0               0
# 3                   0               0               0               0
# 25                  0               0               0               0
# 17                  0               0               0               0
# 16                  0               0               0               0
#
# Stats transAT_PSK_75% transAT_PSK_max Nr_BGCs_count Nr_BGCs_mean Nr_BGCs_std  \
# 10                  0               0           294          7.7         3.4
# 3                   0               0            21          1.1         0.3
# 25                  0               0            48          1.9         0.8
# 17                  0               0            31            2         0.9
# 16                  0               0            41          2.3         0.8
#
# Stats Nr_BGCs_min Nr_BGCs_25% Nr_BGCs_50% Nr_BGCs_75% Nr_BGCs_max  \
# 10              1           6           8           9          31
# 3               1           1           1           1           2
# 25              1           1           2         2.2           3
# 17              1           1           2         2.5           5
# 16              1           2           2           3           5
#
# Stats Known_cluster_count_count Known_cluster_count_mean  \
# 10                          294                      2.8
# 3                             2                        1
# 25                           45                        1
# 17                           29                      1.6
# 16                           39                        2
#
# Stats Known_cluster_count_std Known_cluster_count_min Known_cluster_count_25%  \
# 10                        0.8                       1                       2
# 3                           0                       1                       1
# 25                          0                       1                       1
# 17                        0.6                       1                       1
# 16                        0.7                       1                       2
#
# Stats Known_cluster_count_50% Known_cluster_count_75% Known_cluster_count_max
# 10                          3                       3                       7
# 3                           1                       1                       1
# 25                          1                       1                       1
# 17                          1                       2                       3
# 16                          2                       2                       4

# %%
bgcs_mean = bgc_types.groupby(['Genus']).filter(lambda x:x['Genus'].count()>7).groupby(['Genus', "Family"]).mean()
bgcs_mean = bgcs_mean.reset_index().set_index("Genus")
bgcs_mean = bgcs_mean.fillna(0)
bgcs_mean = bgcs_mean.sort_values(by=["Family", "Genus"])
bgcs_mean.head()
# Out:
#                         Family      NRPS  NRPS_other  PKSI    PKSIII  \
# Genus
# Aequorivita  Flavobacteriaceae  0.000000    0.000000   0.0  0.904762
# Algibacter   Flavobacteriaceae  0.111111    0.000000   0.0  0.000000
# Aquimarina   Flavobacteriaceae  1.769231    0.076923   0.0  0.923077
# Arenibacter  Flavobacteriaceae  0.272727    0.000000   0.0  0.954545
# BACL21       Flavobacteriaceae  0.000000    0.000000   0.0  0.000000
#
#              PKS_other     RiPPs    Others  Siderophore   terpene  \
# Genus
# Aequorivita   0.000000  0.000000  1.023810     0.000000  1.023810
# Algibacter    0.000000  0.000000  0.000000     0.000000  1.000000
# Aquimarina    0.076923  1.564103  0.948718     0.846154  2.000000
# Arenibacter   0.000000  0.045455  0.727273     0.000000  2.681818
# BACL21        0.000000  0.000000  0.000000     0.000000  1.071429
#
#              transAT_PSK   Nr_BGCs  Known_cluster_count
# Genus
# Aequorivita      0.00000  2.952381             1.976190
# Algibacter       0.00000  1.777778             1.111111
# Aquimarina       0.74359  9.512821             3.128205
# Arenibacter      0.00000  4.681818             1.681818
# BACL21           0.00000  1.071429             1.083333

# %% [markdown]
# # Plots

# %%
finalx.head()
# Out:
# Stats             Genus         Family NRPS_count NRPS_mean NRPS_std NRPS_min  \
# 10     Chryseobacterium  Weeksellaceae        294       1.3      1.9        0
# 3             Apibacter  Weeksellaceae         21         0        0        0
# 25            Kaistella  Weeksellaceae         48         0        0        0
# 17      Epilithonimonas  Weeksellaceae         31         0        0        0
# 16         Empedobacter  Weeksellaceae         41         0      0.2        0
#
# Stats NRPS_25% NRPS_50% NRPS_75% NRPS_max NRPS_other_count NRPS_other_mean  \
# 10           0        1        2       24              294             0.2
# 3            0        0        0        0               21               0
# 25           0        0        0        0               48               0
# 17           0        0        0        0               31               0
# 16           0        0        0        1               41               0
#
# Stats NRPS_other_std NRPS_other_min NRPS_other_25% NRPS_other_50%  \
# 10               0.5              0              0              0
# 3                  0              0              0              0
# 25                 0              0              0              0
# 17                 0              0              0              0
# 16                 0              0              0              0
#
# Stats NRPS_other_75% NRPS_other_max PKSI_count PKSI_mean PKSI_std PKSI_min  \
# 10                 0              3        294         0      0.1        0
# 3                  0              0         21         0        0        0
# 25                 0              0         48         0        0        0
# 17                 0              0         31         0        0        0
# 16                 0              0         41         0        0        0
#
# Stats PKSI_25% PKSI_50% PKSI_75% PKSI_max PKSIII_count PKSIII_mean PKSIII_std  \
# 10           0        0        0        2          294           0          0
# 3            0        0        0        0           21           0          0
# 25           0        0        0        0           48         0.6        0.5
# 17           0        0        0        0           31           0          0
# 16           0        0        0        0           41           0          0
#
# Stats PKSIII_min PKSIII_25% PKSIII_50% PKSIII_75% PKSIII_max PKS_other_count  \
# 10             0          0          0          0          0             294
# 3              0          0          0          0          0              21
# 25             0          0          1          1          1              48
# 17             0          0          0          0          0              31
# 16             0          0          0          0          0              41
#
# Stats PKS_other_mean PKS_other_std PKS_other_min PKS_other_25% PKS_other_50%  \
# 10               0.7           0.5             0             0             1
# 3                  1             0             1             1             1
# 25                 0             0             0             0             0
# 17                 0             0             0             0             0
# 16                 0             0             0             0             0
#
# Stats PKS_other_75% PKS_other_max RiPPs_count RiPPs_mean RiPPs_std RiPPs_min  \
# 10                1             2         294        2.4       1.3         0
# 3                 1             1          21          0         0         0
# 25                0             0          48          0       0.1         0
# 17                0             0          31        0.5       0.7         0
# 16                0             0          41        0.2       0.4         0
#
# Stats RiPPs_25% RiPPs_50% RiPPs_75% RiPPs_max Others_count Others_mean  \
# 10            2         2         3         6          294         1.2
# 3             0         0         0         0           21         0.1
# 25            0         0         0         1           48           0
# 17            0         0         1         3           31         0.5
# 16            0         0         0         1           41         1.2
#
# Stats Others_std Others_min Others_25% Others_50% Others_75% Others_max  \
# 10           0.5          1          1          1          1          5
# 3            0.3          0          0          0          0          1
# 25           0.2          0          0          0          0          1
# 17           0.7          0          0          0          1          2
# 16           0.7          0          1          1          1          3
#
# Stats Siderophore_count Siderophore_mean Siderophore_std Siderophore_min  \
# 10                  294              0.7             0.5               0
# 3                    21                0               0               0
# 25                   48                0               0               0
# 17                   31                0               0               0
# 16                   41                0               0               0
#
# Stats Siderophore_25% Siderophore_50% Siderophore_75% Siderophore_max  \
# 10                  0               1               1               2
# 3                   0               0               0               0
# 25                  0               0               0               0
# 17                  0               0               0               0
# 16                  0               0               0               0
#
# Stats terpene_count terpene_mean terpene_std terpene_min terpene_25%  \
# 10              294          1.1         1.1           0           0
# 3                21            0           0           0           0
# 25               48          1.2         0.5           0           1
# 17               31            1         0.3           0           1
# 16               41          0.8         0.5           0           1
#
# Stats terpene_50% terpene_75% terpene_max transAT_PSK_count transAT_PSK_mean  \
# 10              1           1           6               294                0
# 3               0           0           0                21                0
# 25              1           1           2                48                0
# 17              1           1           2                31                0
# 16              1           1           2                41                0
#
# Stats transAT_PSK_std transAT_PSK_min transAT_PSK_25% transAT_PSK_50%  \
# 10                  0               0               0               0
# 3                   0               0               0               0
# 25                  0               0               0               0
# 17                  0               0               0               0
# 16                  0               0               0               0
#
# Stats transAT_PSK_75% transAT_PSK_max Nr_BGCs_count Nr_BGCs_mean Nr_BGCs_std  \
# 10                  0               0           294          7.7         3.4
# 3                   0               0            21          1.1         0.3
# 25                  0               0            48          1.9         0.8
# 17                  0               0            31            2         0.9
# 16                  0               0            41          2.3         0.8
#
# Stats Nr_BGCs_min Nr_BGCs_25% Nr_BGCs_50% Nr_BGCs_75% Nr_BGCs_max  \
# 10              1           6           8           9          31
# 3               1           1           1           1           2
# 25              1           1           2         2.2           3
# 17              1           1           2         2.5           5
# 16              1           2           2           3           5
#
# Stats Known_cluster_count_count Known_cluster_count_mean  \
# 10                          294                      2.8
# 3                             2                        1
# 25                           45                        1
# 17                           29                      1.6
# 16                           39                        2
#
# Stats Known_cluster_count_std Known_cluster_count_min Known_cluster_count_25%  \
# 10                        0.8                       1                       2
# 3                           0                       1                       1
# 25                          0                       1                       1
# 17                        0.6                       1                       1
# 16                        0.7                       1                       2
#
# Stats Known_cluster_count_50% Known_cluster_count_75% Known_cluster_count_max
# 10                          3                       3                       7
# 3                           1                       1                       1
# 25                          1                       1                       1
# 17                          1                       2                       3
# 16                          2                       2                       4

# %%
sns.set_style({'font.family': 'Arial'})
#sns.set(style="whitegrid")
sns.set_context("paper", font_scale=1.3) 

finalx = finalx.sort_values(by=["Family","Genus"])
plt.figure(figsize=(17,10))
g = sns.catplot(
    data=finalx, kind="bar", 
    x='Genus', hue="Family",dodge=False, legend_out=True,
    y='Nr_BGCs_mean', 
    height=6, # make the plot 7 units high
    aspect=2.5) # height is n times width

g._legend.set_bbox_to_anchor((0.12, 0.92))

g.map(plt.errorbar, "Genus", "Nr_BGCs_mean", "Nr_BGCs_std", ls='none', capsize=2, color="dimgrey")

#g.map(plt.scatter(x="Genus",y="Nr_BGCs_max"))

sns.stripplot(x='Genus',y='Nr_BGCs_max', data=finalx, jitter=False, color="orangered", alpha=0.9)
sns.stripplot(x='Genus',y='Nr_BGCs_min', data=finalx, jitter=False, color="darkturquoise", alpha=0.9)

#Second layer, with average known clusters
sns.barplot(x = finalx["Genus"], y =finalx["Known_cluster_count_mean"], data=finalx,color = "#0000A3", alpha=0.2)

plt.xlabel('Genomes grouped per Genus') #, fontsize=15
plt.ylabel('Average nr. BGCs')#fontsize=13

for ax in g.axes.ravel():
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right')

import matplotlib.lines as mlines
red_line = mlines.Line2D([], [], color='orangered', marker='o', ls="",
                          markersize=7, label='Maximum count')
blue_line = mlines.Line2D([], [], color='royalblue', marker='o',ls="",
                          markersize=7, label='Minimum count')
black_line=mlines.Line2D([], [], color='dimgrey', #marker='',
                          markersize=7, label='Standard deviation')
plt.legend(handles=[red_line,blue_line, black_line], bbox_to_anchor=(0.89, 1), loc=(0,2), borderaxespad=0.);

#plt.show()    
ax = plt.gca()
g.savefig("bgcs.pdf")
